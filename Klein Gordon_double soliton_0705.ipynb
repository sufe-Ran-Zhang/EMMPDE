# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import time
from collections import OrderedDict

# 修改参数设置 - double soliton参数
a = 0.3  # Klein-Gordon方程系数
b = 1    # 非线性系数
c1 = 0.25   # 第一个孤立子速度
c2 = -0.25  # 第二个孤立子速度
k1 = np.sqrt(a / (2 * (a**2 - c1**2)))  # 第一个波数
k2 = np.sqrt(a / (2 * (a**2 - c2**2)))  # 第二个波数

nu = 0.1

# %%
# 修改精确解函数 - double soliton形式
def analytical_solution(t, x):
    """
    Klein-Gordon方程精确解 (double soliton形式)
    u(x,t) = sqrt(2a/b) * sech(k1*(x - c1*t + 2)) + sqrt(2a/b) * sech(k2*(x - c2*t - 2))
    """
    sech_term1 = 1.0 / torch.cosh(k1 * (x - c1 * t + 2))
    sech_term2 = 1.0 / torch.cosh(k2 * (x - c2 * t - 2))
    u = torch.sqrt(torch.tensor(2*a/b)) * (sech_term1 + sech_term2)
    return u.reshape(-1, 1)

def analytical_solution_v(t, x):
    """
    v = du/dt 的精确解 (double soliton形式)
    v(x,t) = c1*k1*sqrt(2a/b)*sech(k1*(x-c1*t+2))*tanh(k1*(x-c1*t+2)) +
             c2*k2*sqrt(2a/b)*sech(k2*(x-c2*t-2))*tanh(k2*(x-c2*t-2))
    """
    # 第一个孤立子的贡献
    sech_term1 = 1.0 / torch.cosh(k1 * (x - c1 * t + 2))
    tanh_term1 = torch.tanh(k1 * (x - c1 * t + 2))
    v1 = c1 * k1 * torch.sqrt(torch.tensor(2*a/b)) * sech_term1 * tanh_term1
    
    # 第二个孤立子的贡献
    sech_term2 = 1.0 / torch.cosh(k2 * (x - c2 * t - 2))
    tanh_term2 = torch.tanh(k2 * (x - c2 * t - 2))
    v2 = c2 * k2 * torch.sqrt(torch.tensor(2*a/b)) * sech_term2 * tanh_term2
    
    v = v1 + v2
    return v.reshape(-1, 1)

def initial_condition_u(x):
    """初始条件 u(x,0) = sqrt(2a/b) * (sech(k1*(x+2)) + sech(k2*(x-2)))"""
    sech_term1 = 1.0 / torch.cosh(k1 * (x + 2))
    sech_term2 = 1.0 / torch.cosh(k2 * (x - 2))
    return torch.sqrt(torch.tensor(2*a/b)) * (sech_term1 + sech_term2)

def initial_condition_v(x):
    """初始条件 v(x,0) = c1*k1*sqrt(2a/b)*sech(k1*(x+2))*tanh(k1*(x+2)) +
                           c2*k2*sqrt(2a/b)*sech(k2*(x-2))*tanh(k2*(x-2))"""
    # 第一个孤立子的贡献
    sech_term1 = 1.0 / torch.cosh(k1 * (x + 2))
    tanh_term1 = torch.tanh(k1 * (x + 2))
    v1 = c1 * k1 * torch.sqrt(torch.tensor(2*a/b)) * sech_term1 * tanh_term1
    
    # 第二个孤立子的贡献
    sech_term2 = 1.0 / torch.cosh(k2 * (x - 2))
    tanh_term2 = torch.tanh(k2 * (x - 2))
    v2 = c2 * k2 * torch.sqrt(torch.tensor(2*a/b)) * sech_term2 * tanh_term2
    
    return v1 + v2

# %%
class PINN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(PINN, self).__init__()
        self.linear1 = nn.Linear(input_size, hidden_size)
        self.linear2 = nn.Linear(hidden_size, hidden_size)
        self.linear3 = nn.Linear(hidden_size, hidden_size)
        self.linear4 = nn.Linear(hidden_size, hidden_size)
        self.output = nn.Linear(hidden_size, 2)  # 输出2个变量：u和v
        self.tanh = nn.Tanh()
        self.iter = 0

    def forward(self, x, t=None):
        if t is not None:
            # 分开的x和t作为输入
            inputs = torch.cat([t, x], dim=1)  # 注意顺序是[t,x]
        else:
            # 已经组合的输入
            inputs = x
            
        out = self.linear1(inputs)
        out = self.tanh(out)
        out = self.linear2(out)
        out = self.tanh(out)
        out = self.linear3(out)
        out = self.tanh(out)
        out = self.linear4(out)
        out = self.tanh(out)
        out = self.output(out)
        return out  # 返回[u, v]

# %%
# 从sampling_PDE.py引入的DNN类
class DNN(torch.nn.Module):
    def __init__(self, layers):
        super(DNN, self).__init__()

        # parameters
        self.depth = len(layers) - 1

        # set up layer order dict
        self.activation = torch.nn.Tanh

        layer_list = list()
        for i in range(self.depth - 1):
            layer_list.append(
                ('layer_%d' % i, torch.nn.Linear(layers[i], layers[i + 1]))
            )
            layer_list.append(('activation_%d' % i, self.activation()))

        layer_list.append(
            ('layer_%d' % (self.depth - 1), torch.nn.Linear(layers[-2], layers[-1]))
        )
        layerDict = OrderedDict(layer_list)

        # deploy layers
        self.layers = torch.nn.Sequential(layerDict)

    def forward(self, x):
        out = self.layers(x)
        return out

# MMPDE采样类
class sampling_MMPDE():
    def __init__(self, X_f, u_fun, layers, lb, ub, nu, AdamIter, LBFGSIter):
        # 边界条件
        self.lb = torch.tensor(lb).float()
        self.ub = torch.tensor(ub).float()

        # 数据
        self.t_f = torch.tensor(X_f[:, 0:1], requires_grad=True).float()
        self.x_f = torch.tensor(X_f[:, 1:2], requires_grad=True).float()
        self.fun = u_fun

        self.layers = layers
        self.nu = nu

        # 深度神经网络
        self.dnn = DNN(layers)

        # 优化器设置
        self.optimizer_Adam = torch.optim.Adam(self.dnn.parameters(),
                                              lr=1e-3,
                                              betas=(0.9, 0.999),
                                              eps=1e-8)
        
        self.AdamIter = AdamIter

        self.optimizer_LBFGS = torch.optim.LBFGS(
            self.dnn.parameters(),
            lr=0.5,
            max_iter=LBFGSIter,
        )

        self.optimizer = None
        self.loss = None
        self.iter = 0
        self.start_time = None

    def detach(self, data):
        return data.detach().cpu().numpy()

    def monitor(self, u, t, x):

        # 计算u对t的一阶导数
        u_t = torch.autograd.grad(
            u, t,
            grad_outputs=torch.ones_like(u),
            retain_graph=True,
            create_graph=True
        )[0]
        
        # 计算u对t的二阶导数(utt)
        u_tt = torch.autograd.grad(
            u_t, t,
            grad_outputs=torch.ones_like(u_t),
            retain_graph=True,
            create_graph=True
        )[0]
        
        # 计算u对x的一阶导数
        u_x = torch.autograd.grad(
            u, x,
            grad_outputs=torch.ones_like(u),
            retain_graph=True,
            create_graph=True
        )[0]
        
        # 计算u对x的二阶导数(uxx)
        u_xx = torch.autograd.grad(
            u_x, x,
            grad_outputs=torch.ones_like(u_x),
            retain_graph=True,
            create_graph=True
        )[0]
        
        # w = (1 + u_xx ** 2 + u_tt ** 2) ** (1 / 2)
        w = (1 + (0.3 * u_xx ** 2) + (0.4 * u_tt ** 2)) ** (1 / 2)
        # w = (1 + u_t ** 2 - a **2 * u_x ** 2 + a * u ** 2 - b/2 * u ** 4) ** (1 / 2)
        # w = (1 + u_x ** 2) ** (1 / 2)  
        
        return w

    def net_sample(self, t, x):
        # 生成新的采样点
        xNew = self.dnn(torch.cat([t, x], dim=1))
        g0 = x - self.lb[1]
        g1 = x - self.ub[1]
        xNew = g0*g1*xNew + x
        return xNew

    def net_f(self, t, x):
        # 计算MMPDE方程的残差
        xNew = self.net_sample(t, x)

        xNew_t = torch.autograd.grad(
            xNew, t,
            grad_outputs=torch.ones_like(xNew),
            retain_graph=True,
            create_graph=True
        )[0]

        xNew_x = torch.autograd.grad(
            xNew, x,
            grad_outputs=torch.ones_like(xNew),
            retain_graph=True,
            create_graph=True
        )[0]
        
        xNew_xx = torch.autograd.grad(
            xNew_x, x,
            grad_outputs=torch.ones_like(xNew_x),
            retain_graph=True,
            create_graph=True
        )[0]

        # 计算解及其导数
        u = self.fun(torch.cat([t, x], dim=1))
        
        # 直接调用修改后的monitor函数，传入u,t,x
        G = self.monitor(u, t, x)

        G_t = torch.autograd.grad(
            G, t,
            grad_outputs=torch.ones_like(G),
            retain_graph=True,
            create_graph=True
        )[0]

        G_x = torch.autograd.grad(
            G, x,
            grad_outputs=torch.ones_like(G),
            retain_graph=True,
            create_graph=True
        )[0]

        # 不再需要G_tx的计算，因为我们已经在monitor函数中处理了二阶导数

        E = G_x * xNew_x + G * xNew_xx
        f = xNew_t*self.nu*(G**2)*(xNew_x**2) + E

        return f

    def loss_func(self):
        # 计算损失函数
        f_pred = self.net_f(self.t_f, self.x_f)
        loss_f = torch.mean(f_pred ** 2)
        
        return loss_f

    def optimize_one_epoch(self):
        if self.start_time is None:
            self.start_time = time.time()

        # 损失函数初始化
        self.optimizer.zero_grad()
        self.loss = self.loss_func()
        self.loss.backward()
        self.iter = self.iter + 1

        if self.iter % 100 == 0:
            loss = self.detach(self.loss)
            print(f"{self.optimizer_name} Iter {self.iter}, Loss: {loss:.6f}")
            elapsed = time.time() - self.start_time
            print(f'Time: {elapsed:.4f}s')
            self.start_time = time.time()

        return self.loss

    def train_Adam(self, optimizer, nIter):
        self.optimizer = optimizer
        self.optimizer_name = 'MMPDE_Adam'
        
        for it in range(nIter):
            self.optimize_one_epoch()
            self.optimizer.step()

    def train_LBFGS(self, optimizer):
        self.optimizer = optimizer
        self.optimizer_name = 'MMPDE_LBFGS'

        def closure():
            loss = self.optimize_one_epoch()
            return loss

        self.optimizer.step(closure)

    def train(self):
        # 训练过程
        print("开始MMPDE训练...")
        self.train_Adam(self.optimizer_Adam, self.AdamIter)
        print("MMPDE_Adam 完成!")
        self.train_LBFGS(self.optimizer_LBFGS)
        print('MMPDE_LBGFS 完成!')

        # 返回新的采样点
        new_x = self.net_sample(self.t_f, self.x_f)
        new_sample = torch.cat([self.t_f, new_x], dim=1)
        return new_sample

# %%
def create_simulation_function(model=None):
    """创建仿真函数，返回u和v的精确解"""
    def simulation_function(xt):
        t, x = xt[:, 0:1], xt[:, 1:2]
        u = analytical_solution(t, x)
        v = analytical_solution_v(t, x)
        return torch.cat([u, v], dim=1)
        
    return simulation_function

# %%
# 修改时空域范围 - double soliton的域
lb = [0.0, -10.0]  # [t_min, x_min] 
ub = [8.0, 10.0]   # [t_max, x_max] - 时间域改为[0, 8]

# 生成均匀分布的采样点
num_samples_per_dim = int(np.sqrt(5000))  # 每个维度上采样约100个点
x_uniform = torch.linspace(-10, 10, num_samples_per_dim)  # x范围[-10,10]
t_uniform = torch.linspace(0, 8, num_samples_per_dim)   # t范围改为[0,8]

# 创建均匀网格
X_grid, T_grid = torch.meshgrid(x_uniform, t_uniform, indexing='ij')
x_init = X_grid.reshape(-1, 1)
t_init = T_grid.reshape(-1, 1)

# 合并为输入样本
X_f_init = torch.cat([t_init, x_init], dim=1).numpy()

# 创建模拟函数
sim_func = create_simulation_function()

# 定义MMPDE参数
mmpde_layers = [2, 20, 20, 20, 1]  # 输入(t,x)，输出新的x坐标
adam_iter = 5000
lbfgs_iter = 1000

# 创建MMPDE采样器并训练
mmpde_sampler = sampling_MMPDE(
    X_f=X_f_init,
    u_fun=sim_func,
    layers=mmpde_layers,
    lb=lb,
    ub=ub,
    nu=nu,
    AdamIter=adam_iter,
    LBFGSIter=lbfgs_iter
)

# 训练MMPDE并获取优化后的采样点
new_samples = mmpde_sampler.train()

# 提取优化后的采样点
t_colloc = new_samples[:, 0:1].clone().detach().requires_grad_(True)
x_colloc = new_samples[:, 1:2].clone().detach().requires_grad_(True)
x_colloc_combined = torch.cat([t_colloc, x_colloc], dim=1)

# 生成边界条件点（齐次Neumann边界条件在x=-10和x=10处）
N_bc = 1000
t_bc = torch.rand(N_bc, 1) * (ub[0] - lb[0]) + lb[0]  # t ∈ [0, 8]
x_bc_left = torch.full((N_bc//2, 1), -10.0)  # x = -10
x_bc_right = torch.full((N_bc//2, 1), 10.0)  # x = 10
x_bc = torch.cat([x_bc_left, x_bc_right], dim=0)
t_bc_split = torch.split(t_bc, N_bc//2)
x_bc_left_combined = torch.cat([t_bc_split[0], x_bc_left], dim=1)
x_bc_right_combined = torch.cat([t_bc_split[1], x_bc_right], dim=1)
x_bc_combined = torch.cat([x_bc_left_combined, x_bc_right_combined], dim=0)
x_bc_combined.requires_grad_(True)

# 初始条件点(t=0)
N_ic = 1000
x_ic = torch.rand(N_ic, 1) * 20 - 10  # x ∈ [-10, 10]
t_ic = torch.zeros(N_ic, 1)
x_ic_combined = torch.cat([t_ic, x_ic], dim=1)
x_ic_combined.requires_grad_(True)
# Out:
# 开始MMPDE训练...
# MMPDE_Adam Iter 100, Loss: 0.234567
# Time: 2.5320s
# MMPDE_Adam Iter 200, Loss: 0.145850
# Time: 2.4523s
# MMPDE_Adam Iter 300, Loss: 0.105670
# Time: 2.4545s
# MMPDE_Adam Iter 400, Loss: 0.085552
# Time: 2.4752s
# MMPDE_Adam Iter 500, Loss: 0.075136
# Time: 2.3715s
# MMPDE_Adam Iter 600, Loss: 0.069123
# Time: 2.4373s
# MMPDE_Adam Iter 700, Loss: 0.065123
# Time: 2.3552s
# MMPDE_Adam Iter 800, Loss: 0.062185
# Time: 2.3482s
# MMPDE_Adam Iter 900, Loss: 0.059913
# Time: 2.3900s
# MMPDE_Adam Iter 1000, Loss: 0.058110
# Time: 2.3744s
# MMPDE_Adam Iter 1100, Loss: 0.056656
# Time: 2.3670s
# MMPDE_Adam Iter 1200, Loss: 0.055467
# Time: 2.4467s
# MMPDE_Adam Iter 1300, Loss: 0.054478
# Time: 2.4261s
# MMPDE_Adam Iter 1400, Loss: 0.053639
# Time: 2.3685s
# MMPDE_Adam Iter 1500, Loss: 0.052915
# Time: 2.3318s
# MMPDE_Adam Iter 1600, Loss: 0.052276
# Time: 2.3742s
# MMPDE_Adam Iter 1700, Loss: 0.051704
# Time: 2.3811s
# MMPDE_Adam Iter 1800, Loss: 0.051184
# Time: 2.3833s
# MMPDE_Adam Iter 1900, Loss: 0.050706
# Time: 2.3841s
# MMPDE_Adam Iter 2000, Loss: 0.050264
# Time: 2.3963s
# MMPDE_Adam Iter 2100, Loss: 0.049850
# Time: 2.3488s
# MMPDE_Adam Iter 2200, Loss: 0.049461
# Time: 2.3952s
# MMPDE_Adam Iter 2300, Loss: 0.049093
# Time: 2.4155s
# MMPDE_Adam Iter 2400, Loss: 0.048741
# Time: 2.3776s
# MMPDE_Adam Iter 2500, Loss: 0.048403
# Time: 2.4616s
# MMPDE_Adam Iter 2600, Loss: 0.048074
# Time: 2.4543s
# MMPDE_Adam Iter 2700, Loss: 0.047751
# Time: 2.5437s
# MMPDE_Adam Iter 2800, Loss: 0.047431
# Time: 2.4426s
# MMPDE_Adam Iter 2900, Loss: 0.047111
# Time: 2.4312s
# MMPDE_Adam Iter 3000, Loss: 0.046787
# Time: 2.4091s
# MMPDE_Adam Iter 3100, Loss: 0.046458
# Time: 2.4889s
# MMPDE_Adam Iter 3200, Loss: 0.046122
# Time: 2.4362s
# MMPDE_Adam Iter 3300, Loss: 0.045777
# Time: 2.3912s
# MMPDE_Adam Iter 3400, Loss: 0.045424
# Time: 2.4623s
# MMPDE_Adam Iter 3500, Loss: 0.045065
# Time: 2.3591s
# MMPDE_Adam Iter 3600, Loss: 0.044703
# Time: 2.3924s
# MMPDE_Adam Iter 3700, Loss: 0.044371
# Time: 2.3840s
# MMPDE_Adam Iter 3800, Loss: 0.044017
# Time: 2.3616s
# MMPDE_Adam Iter 3900, Loss: 0.044144
# Time: 2.3952s
# MMPDE_Adam Iter 4000, Loss: 0.043358
# Time: 2.3481s
# MMPDE_Adam Iter 4100, Loss: 0.043011
# Time: 2.3916s
# MMPDE_Adam Iter 4200, Loss: 0.042727
# Time: 2.3704s
# MMPDE_Adam Iter 4300, Loss: 0.042351
# Time: 2.3660s
# MMPDE_Adam Iter 4400, Loss: 0.042297
# Time: 2.4091s
# MMPDE_Adam Iter 4500, Loss: 0.041677
# Time: 2.3793s
# MMPDE_Adam Iter 4600, Loss: 0.041295
# Time: 2.3855s
# MMPDE_Adam Iter 4700, Loss: 0.042732
# Time: 2.3502s
# MMPDE_Adam Iter 4800, Loss: 0.040588
# Time: 2.3691s
# MMPDE_Adam Iter 4900, Loss: 0.040176
# Time: 2.4016s
# MMPDE_Adam Iter 5000, Loss: 0.039749
# Time: 2.3923s
# MMPDE_Adam 完成!
# MMPDE_LBFGS Iter 5100, Loss: 0.035232
# Time: 2.4029s
# MMPDE_LBFGS Iter 5200, Loss: 0.032469
# Time: 2.5240s
# MMPDE_LBFGS Iter 5300, Loss: 0.031298
# Time: 2.5410s
# MMPDE_LBFGS Iter 5400, Loss: 0.030148
# Time: 2.5331s
# MMPDE_LBFGS Iter 5500, Loss: 0.029028
# Time: 2.5038s
# MMPDE_LBFGS Iter 5600, Loss: 0.028160
# Time: 2.5916s
# MMPDE_LBFGS Iter 5700, Loss: 0.027474
# Time: 2.5444s
# MMPDE_LBFGS Iter 5800, Loss: 0.026794
# Time: 2.4990s
# MMPDE_LBFGS Iter 5900, Loss: 0.026035
# Time: 2.5287s
# MMPDE_LBFGS Iter 6000, Loss: 0.025503
# Time: 2.6783s
# MMPDE_LBGFS 完成!
# tensor([[ 0.0000, -3.3698],
#         [ 0.0000,  3.1836],
#         [ 0.0000,  0.1059],
#         ...,
#         [ 0.0000, -6.2872],
#         [ 0.0000,  5.5978],
#         [ 0.0000,  2.7256]], requires_grad=True)

# %%
# 可视化采样点
plt.figure(figsize=(10, 6))
plt.scatter(t_colloc.detach().numpy(), x_colloc.detach().numpy(), color='blue', alpha=0.5, label='Collocation', s=10)
plt.xlabel('$t$', fontsize=20)
plt.ylabel('$x$', fontsize=20)
plt.grid(True, alpha=0.5, linestyle='-', linewidth=0.5)
plt.show()

# %%
def x_f_loss_fun(inputs, model):
    """
    计算Klein-Gordon方程PDE残差（一阶系统形式）:
    du/dt = v
    dv/dt = a^2 * u_xx - a * u + b * u^3
    """
    if not inputs.requires_grad:
        inputs = Variable(inputs, requires_grad=True)
    
    # 获取模型预测的u和v
    outputs = model(inputs)
    u = outputs[:, 0:1]  # 第一个输出是u
    v = outputs[:, 1:2]  # 第二个输出是v
    
    # 提取坐标
    t = inputs[:, 0:1]
    x = inputs[:, 1:2]
    
    # 计算u关于输入的梯度
    u_grad = torch.autograd.grad(u, inputs, grad_outputs=torch.ones_like(u), create_graph=True)[0]
    u_t = u_grad[:, 0:1]  # du/dt
    u_x = u_grad[:, 1:2]  # du/dx
    
    # 计算v关于输入的梯度
    v_grad = torch.autograd.grad(v, inputs, grad_outputs=torch.ones_like(v), create_graph=True)[0]
    v_t = v_grad[:, 0:1]  # dv/dt
    
    # 计算u_xx - 对u_x再求一次关于x的导数
    u_xx = torch.autograd.grad(u_x, inputs, grad_outputs=torch.ones_like(u_x), create_graph=True)[0][:, 1:2]
    
    # 计算PDE残差
    # 第一个方程：du/dt = v
    f1 = u_t - v
    
    # 第二个方程：dv/dt = a^2 * u_xx - a * u + b * u^3
    f2 = v_t - (a**2 * u_xx - a * u + b * (u**3))
    
    return torch.cat([f1, f2], dim=1)

# %%
# 修改边界条件函数 - double soliton使用齐次Neumann边界条件
def boundary_loss(model, x_bc):
    """
    边界条件损失：double soliton的齐次Neumann边界条件
    u_x(-10, t) = u_x(10, t) = 0
    """
    inputs = x_bc.clone().requires_grad_(True)
    outputs = model(inputs)
    u = outputs[:, 0:1]  # 获取u
    
    # 计算u_x
    u_x = torch.autograd.grad(
        u, inputs,
        grad_outputs=torch.ones_like(u),
        create_graph=True
    )[0][:, 1:2]  # 对x的导数
    
    # 齐次Neumann边界条件：u_x = 0 在边界处
    return torch.mean(u_x**2)

def initial_condition_loss(model, x_ic):
    """
    初始条件损失：
    1. u(x,0) = sqrt(2a/b) * sech(kx)
    2. v(x,0) = c * k * sqrt(2a/b) * sech(kx) * tanh(kx)
    """
    outputs = model(x_ic)
    u_pred = outputs[:, 0:1]
    v_pred = outputs[:, 1:2]
    
    # 提取x坐标
    x = x_ic[:, 1:2]
    
    # 计算初始条件目标值
    u_ic_target = initial_condition_u(x)
    v_ic_target = initial_condition_v(x)
    
    # 计算损失
    u_loss = torch.mean((u_pred - u_ic_target)**2)
    v_loss = torch.mean((v_pred - v_ic_target)**2)
    
    return u_loss + v_loss

# %%
# 创建模型
model = PINN(2, 40)  # 输入维度是2 (t和x)，隐藏层维度40
model.iter = 0  # 添加迭代计数器

# 优化器参数
adam_iter = 5000  # Adam迭代次数
lbfgs_iter = 10000  # LBFGS迭代次数
adam_lr = 0.001  # Adam学习率
lbfgs_lr = 0.5  # LBFGS学习率

# 定义Adam优化器
optimizer_adam = torch.optim.Adam(model.parameters(), lr=adam_lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer_adam, step_size=1000, gamma=0.5)

# 第一阶段：Adam优化
print("开始第一阶段: Adam优化...")
for epoch in range(adam_iter):
    optimizer_adam.zero_grad()
    
    # 计算PDE残差
    f = x_f_loss_fun(x_colloc_combined, model)
    loss_pde = torch.mean(f**2)
    
    # 计算边界条件损失
    loss_bc = boundary_loss(model, x_bc_combined)
    
    # 计算初始条件损失
    loss_ic = initial_condition_loss(model, x_ic_combined)
    
    # 总损失
    total_loss = loss_pde + 10.0 * loss_bc + 10.0 * loss_ic
    
    total_loss.backward()
    
    # 添加梯度裁剪
    torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
    
    optimizer_adam.step()
    scheduler.step()
    model.iter += 1
    
    if epoch % 100 == 0:
        print(f"Epoch: {epoch}/{adam_iter}, "
              f"Loss: {total_loss.item():.6e}, "
              f"PDE: {loss_pde.item():.6e}, "
              f"BC: {loss_bc.item():.6e}, "
              f"IC: {loss_ic.item():.6e}")

# 定义LBFGS优化器
optimizer_lbfgs = torch.optim.LBFGS(
    model.parameters(), 
    lr=lbfgs_lr, 
    max_iter=20,
    max_eval=25,
    tolerance_grad=1e-9,
    tolerance_change=1e-12,
    history_size=50,
    line_search_fn="strong_wolfe"
)

# 第二阶段：LBFGS优化
print("开始第二阶段: LBFGS优化...")

# 在训练循环中修改损失计算
def closure():
    optimizer_lbfgs.zero_grad()
    
    # 计算PDE残差
    f = x_f_loss_fun(x_colloc_combined, model)
    loss_pde = torch.mean(f**2)  # f现在是2列的矩阵
    
    # 计算边界条件损失
    loss_bc = boundary_loss(model, x_bc_combined)
    
    # 计算初始条件损失
    loss_ic = initial_condition_loss(model, x_ic_combined)
    
    # 总损失
    total_loss = loss_pde + 10.0 * loss_bc + 10.0 * loss_ic
    
    total_loss.backward()
    
    model.iter += 1
    if model.iter % 100 == 0:
        print(f"LBFGS Iter: {model.iter}, "
              f"Loss: {total_loss.item():.6e}, "
              f"PDE: {loss_pde.item():.6e}, "
              f"BC: {loss_bc.item():.6e}, "
              f"IC: {loss_ic.item():.6e}")
    
    return total_loss

# 运行LBFGS优化
for i in range(lbfgs_iter // 20):  # 由于max_iter设为20，我们在外层循环控制总迭代次数
    optimizer_lbfgs.step(closure)
    current_loss = closure()
    print(f"LBFGS外循环 {i+1}/{lbfgs_iter//20}, 当前损失: {current_loss.item():.6e}")

print("优化完成!")
# Out:
# 开始第一阶段: Adam优化...
# Epoch: 0/5000, Loss: 9.359439e-01, PDE: 8.729258e-03, BC: 1.537989e-05, IC: 9.270608e-02
# Epoch: 100/5000, Loss: 1.580163e-01, PDE: 7.964753e-04, BC: 2.906836e-05, IC: 1.569291e-02
# Epoch: 200/5000, Loss: 1.291527e-01, PDE: 6.924497e-04, BC: 1.262201e-05, IC: 1.283340e-02
# Epoch: 300/5000, Loss: 9.467404e-02, PDE: 6.866224e-04, BC: 1.312314e-05, IC: 9.385619e-03
# Epoch: 400/5000, Loss: 7.826909e-02, PDE: 9.704631e-04, BC: 9.832210e-06, IC: 7.720031e-03
# Epoch: 500/5000, Loss: 4.297777e-02, PDE: 6.408463e-04, BC: 5.965462e-06, IC: 4.227727e-03
# Epoch: 600/5000, Loss: 2.543835e-02, PDE: 7.334567e-04, BC: 5.647666e-06, IC: 2.464842e-03
# Epoch: 700/5000, Loss: 1.500043e-02, PDE: 6.383333e-04, BC: 4.057779e-06, IC: 1.432152e-03
# Epoch: 800/5000, Loss: 9.105884e-03, PDE: 5.195371e-04, BC: 2.889509e-06, IC: 8.557452e-04
# Epoch: 900/5000, Loss: 5.294781e-03, PDE: 4.135638e-04, BC: 1.857037e-06, IC: 4.862646e-04
# Epoch: 1000/5000, Loss: 4.125060e-03, PDE: 3.714475e-04, BC: 1.154946e-06, IC: 3.742063e-04
# Epoch: 1100/5000, Loss: 2.026246e-03, PDE: 2.870985e-04, BC: 8.901638e-07, IC: 1.730246e-04
# Epoch: 1200/5000, Loss: 1.589545e-03, PDE: 2.644085e-04, BC: 6.524717e-07, IC: 1.318612e-04
# Epoch: 1300/5000, Loss: 1.303969e-03, PDE: 2.464205e-04, BC: 4.709769e-07, IC: 1.052839e-04
# Epoch: 1400/5000, Loss: 1.098725e-03, PDE: 2.310144e-04, BC: 3.537592e-07, IC: 8.641735e-05
# Epoch: 1500/5000, Loss: 9.423629e-04, PDE: 2.173039e-04, BC: 2.878621e-07, IC: 7.221804e-05
# Epoch: 1600/5000, Loss: 8.184441e-04, PDE: 2.048723e-04, BC: 2.552327e-07, IC: 6.110194e-05
# Epoch: 1700/5000, Loss: 7.175045e-04, PDE: 1.935591e-04, BC: 2.406433e-07, IC: 5.215390e-05
# Epoch: 1800/5000, Loss: 6.337709e-04, PDE: 1.833261e-04, BC: 2.343278e-07, IC: 4.481016e-05
# Epoch: 1900/5000, Loss: 5.633353e-04, PDE: 1.740186e-04, BC: 2.307760e-07, IC: 3.870089e-05
# Epoch: 2000/5000, Loss: 5.033695e-04, PDE: 1.654502e-04, BC: 2.267457e-07, IC: 3.356518e-05
# Epoch: 2100/5000, Loss: 4.763724e-04, PDE: 1.613415e-04, BC: 2.238356e-07, IC: 3.127925e-05
# Epoch: 2200/5000, Loss: 4.506035e-04, PDE: 1.572584e-04, BC: 2.201730e-07, IC: 2.911434e-05
# Epoch: 2300/5000, Loss: 4.260145e-04, PDE: 1.531975e-04, BC: 2.156799e-07, IC: 2.706601e-05
# Epoch: 2400/5000, Loss: 4.025674e-04, PDE: 1.491592e-04, BC: 2.103336e-07, IC: 2.513049e-05
# Epoch: 2500/5000, Loss: 3.802188e-04, PDE: 1.451438e-04, BC: 2.041725e-07, IC: 2.330333e-05
# Epoch: 2600/5000, Loss: 3.589265e-04, PDE: 1.411543e-04, BC: 1.972757e-07, IC: 2.157994e-05
# Epoch: 2700/5000, Loss: 3.386488e-04, PDE: 1.371924e-04, BC: 1.897803e-07, IC: 1.995586e-05
# Epoch: 2800/5000, Loss: 3.193443e-04, PDE: 1.332617e-04, BC: 1.818539e-07, IC: 1.842641e-05
# Epoch: 2900/5000, Loss: 3.009722e-04, PDE: 1.293642e-04, BC: 1.736884e-07, IC: 1.698712e-05
# Epoch: 3000/5000, Loss: 2.834955e-04, PDE: 1.255024e-04, BC: 1.654932e-07, IC: 1.563382e-05
# Epoch: 3100/5000, Loss: 2.749906e-04, PDE: 1.235625e-04, BC: 1.613923e-07, IC: 1.498142e-05
# Epoch: 3200/5000, Loss: 2.664916e-04, PDE: 1.215836e-04, BC: 1.572715e-07, IC: 1.433352e-05
# Epoch: 3300/5000, Loss: 2.580108e-04, PDE: 1.195666e-04, BC: 1.531614e-07, IC: 1.369125e-05
# Epoch: 3400/5000, Loss: 2.495621e-04, PDE: 1.175134e-04, BC: 1.491022e-07, IC: 1.305578e-05
# Epoch: 3500/5000, Loss: 2.411619e-04, PDE: 1.154257e-04, BC: 1.451352e-07, IC: 1.242849e-05
# Epoch: 3600/5000, Loss: 2.328244e-04, PDE: 1.133063e-04, BC: 1.413004e-07, IC: 1.181051e-05
# Epoch: 3700/5000, Loss: 2.245667e-04, PDE: 1.111589e-04, BC: 1.376332e-07, IC: 1.120314e-05
# Epoch: 3800/5000, Loss: 2.164060e-04, PDE: 1.089881e-04, BC: 1.341679e-07, IC: 1.060761e-05
# Epoch: 3900/5000, Loss: 2.083620e-04, PDE: 1.068002e-04, BC: 1.309206e-07, IC: 1.002527e-05
# Epoch: 4000/5000, Loss: 2.004548e-04, PDE: 1.046026e-04, BC: 1.278952e-07, IC: 9.457328e-06
# Epoch: 4100/5000, Loss: 1.965159e-04, PDE: 1.034905e-04, BC: 1.264382e-07, IC: 9.176107e-06
# Epoch: 4200/5000, Loss: 1.925254e-04, PDE: 1.023528e-04, BC: 1.249846e-07, IC: 8.892272e-06
# Epoch: 4300/5000, Loss: 1.884896e-04, PDE: 1.011911e-04, BC: 1.235332e-07, IC: 8.606320e-06
# Epoch: 4400/5000, Loss: 1.844166e-04, PDE: 1.000078e-04, BC: 1.220722e-07, IC: 8.318808e-06
# Epoch: 4500/5000, Loss: 1.803154e-04, PDE: 9.880527e-05, BC: 1.205936e-07, IC: 8.030418e-06
# Epoch: 4600/5000, Loss: 1.761949e-04, PDE: 9.758607e-05, BC: 1.190850e-07, IC: 7.741802e-06
# Epoch: 4700/5000, Loss: 1.720649e-04, PDE: 9.635322e-05, BC: 1.175282e-07, IC: 7.453637e-06
# Epoch: 4800/5000, Loss: 1.679352e-04, PDE: 9.510985e-05, BC: 1.159081e-07, IC: 7.166627e-06
# Epoch: 4900/5000, Loss: 1.638154e-04, PDE: 9.385846e-05, BC: 1.142117e-07, IC: 6.881485e-06
# 开始第二阶段: LBFGS优化...
# LBFGS外循环 1/500, 当前损失: 1.401470e-04
# LBFGS外循环 2/500, 当前损失: 1.157405e-04
# LBFGS外循环 3/500, 当前损失: 1.039912e-04
# LBFGS外循环 4/500, 当前损失: 9.616951e-05
# LBFGS Iter: 5100, Loss: 9.421336e-05, PDE: 7.471701e-05, BC: 4.882715e-08, IC: 1.900807e-06
# LBFGS外循环 5/500, 当前损失: 8.911075e-05
# LBFGS外循环 6/500, 当前损失: 8.688067e-05
# LBFGS外循环 7/500, 当前损失: 8.491988e-05
# LBFGS外循环 8/500, 当前损失: 8.122629e-05
# LBFGS Iter: 5200, Loss: 7.984541e-05, PDE: 6.638341e-05, BC: 4.679074e-08, IC: 1.299409e-06
# LBFGS外循环 9/500, 当前损失: 7.902573e-05
# LBFGS外循环 10/500, 当前损失: 7.620696e-05
# LBFGS外循环 11/500, 当前损失: 7.342364e-05
# LBFGS外循环 12/500, 当前损失: 7.165598e-05
# LBFGS外循环 13/500, 当前损失: 6.930791e-05
# LBFGS Iter: 5300, Loss: 6.883757e-05, PDE: 5.872705e-05, BC: 2.161629e-08, IC: 9.894352e-07
# LBFGS外循环 14/500, 当前损失: 6.819503e-05
# LBFGS外循环 15/500, 当前损失: 6.668696e-05
# LBFGS外循环 16/500, 当前损失: 6.598818e-05
# LBFGS外循环 17/500, 当前损失: 6.332363e-05
# LBFGS Iter: 5400, Loss: 6.203756e-05, PDE: 5.306448e-05, BC: 2.027786e-08, IC: 8.770313e-07
# LBFGS外循环 18/500, 当前损失: 6.176457e-05
# LBFGS外循环 19/500, 当前损失: 6.032179e-05
# LBFGS外循环 20/500, 当前损失: 5.886463e-05
# LBFGS外循环 21/500, 当前损失: 5.690429e-05
# LBFGS外循环 22/500, 当前损失: 5.476132e-05
# LBFGS Iter: 5500, Loss: 5.455090e-05, PDE: 4.693641e-05, BC: 4.930843e-08, IC: 7.121409e-07
# LBFGS外循环 23/500, 当前损失: 5.362467e-05
# LBFGS外循环 24/500, 当前损失: 5.202584e-05
# LBFGS外循环 25/500, 当前损失: 5.119901e-05
# LBFGS外循环 26/500, 当前损失: 5.056637e-05
# LBFGS Iter: 5600, Loss: 5.013241e-05, PDE: 4.491035e-05, BC: 1.184406e-08, IC: 5.103625e-07
# LBFGS外循环 27/500, 当前损失: 4.978551e-05
# LBFGS外循环 28/500, 当前损失: 4.906753e-05
# LBFGS外循环 29/500, 当前损失: 4.811005e-05
# LBFGS外循环 30/500, 当前损失: 4.733221e-05
# LBFGS外循环 31/500, 当前损失: 4.673326e-05
# LBFGS Iter: 5700, Loss: 4.661001e-05, PDE: 4.219016e-05, BC: 2.822648e-08, IC: 4.137582e-07
# LBFGS外循环 32/500, 当前损失: 4.579421e-05
# LBFGS外循环 33/500, 当前损失: 4.540526e-05
# LBFGS外循环 34/500, 当前损失: 4.472767e-05
# LBFGS外循环 35/500, 当前损失: 4.416881e-05
# LBFGS Iter: 5800, Loss: 4.384273e-05, PDE: 3.986094e-05, BC: 2.134734e-08, IC: 3.768316e-07
# LBFGS外循环 36/500, 当前损失: 4.366833e-05
# LBFGS外循环 37/500, 当前损失: 4.319669e-05
# LBFGS外循环 38/500, 当前损失: 4.244830e-05
# LBFGS外循环 39/500, 当前损失: 4.196294e-05
# LBFGS Iter: 5900, Loss: 4.154217e-05, PDE: 3.782416e-05, BC: 9.490076e-09, IC: 3.623108e-07
# LBFGS外循环 40/500, 当前损失: 4.154217e-05
# LBFGS外循环 41/500, 当前损失: 4.053590e-05
# LBFGS外循环 42/500, 当前损失: 3.954128e-05
# LBFGS外循环 43/500, 当前损失: 3.894174e-05
# LBFGS外循环 44/500, 当前损失: 3.761385e-05
# LBFGS Iter: 6000, Loss: 3.710472e-05, PDE: 3.360843e-05, BC: 1.753876e-08, IC: 3.320906e-07
# LBFGS外循环 45/500, 当前损失: 3.648031e-05
# LBFGS外循环 46/500, 当前损失: 3.578109e-05
# LBFGS外循环 47/500, 当前损失: 3.527850e-05
# LBFGS外循环 48/500, 当前损失: 3.472212e-05
# LBFGS Iter: 6100, Loss: 3.441061e-05, PDE: 3.188174e-05, BC: 2.674884e-08, IC: 2.261386e-07
# LBFGS外循环 49/500, 当前损失: 3.428527e-05
# LBFGS外循环 50/500, 当前损失: 3.360559e-05
# LBFGS外循环 51/500, 当前损失: 3.279954e-05
# LBFGS外循环 52/500, 当前损失: 3.236627e-05
# LBFGS外循环 53/500, 当前损失: 3.175671e-05
# LBFGS Iter: 6200, Loss: 3.164831e-05, PDE: 2.954317e-05, BC: 1.736418e-08, IC: 1.931495e-07
# LBFGS外循环 54/500, 当前损失: 3.136220e-05
# LBFGS外循环 55/500, 当前损失: 3.107094e-05
# LBFGS外循环 56/500, 当前损失: 3.056677e-05
# LBFGS外循环 57/500, 当前损失: 3.034790e-05
# LBFGS Iter: 6300, Loss: 3.002410e-05, PDE: 2.805074e-05, BC: 9.144173e-09, IC: 1.881920e-07
# LBFGS外循环 58/500, 当前损失: 2.988532e-05
# LBFGS外循环 59/500, 当前损失: 2.959685e-05
# LBFGS外循环 60/500, 当前损失: 2.903884e-05
# LBFGS外循环 61/500, 当前损失: 2.871213e-05
# LBFGS外循环 62/500, 当前损失: 2.835173e-05
# LBFGS Iter: 6400, Loss: 2.832296e-05, PDE: 2.644174e-05, BC: 7.672530e-09, IC: 1.804494e-07
# LBFGS外循环 63/500, 当前损失: 2.785384e-05
# LBFGS外循环 64/500, 当前损失: 2.757265e-05
# LBFGS外循环 65/500, 当前损失: 2.707984e-05
# LBFGS外循环 66/500, 当前损失: 2.643240e-05
# LBFGS Iter: 6500, Loss: 2.618675e-05, PDE: 2.457831e-05, BC: 9.987259e-09, IC: 1.508568e-07
# LBFGS外循环 67/500, 当前损失: 2.590387e-05
# LBFGS外循环 68/500, 当前损失: 2.565744e-05
# LBFGS外循环 69/500, 当前损失: 2.551427e-05
# LBFGS外循环 70/500, 当前损失: 2.516831e-05
# LBFGS Iter: 6600, Loss: 2.501474e-05, PDE: 2.360645e-05, BC: 4.622285e-09, IC: 1.362061e-07
# LBFGS外循环 71/500, 当前损失: 2.500351e-05
# LBFGS外循环 72/500, 当前损失: 2.479383e-05
# LBFGS外循环 73/500, 当前损失: 2.464123e-05
# LBFGS外循环 74/500, 当前损失: 2.445478e-05
# LBFGS外循环 75/500, 当前损失: 2.425818e-05
# LBFGS Iter: 6700, Loss: 2.417937e-05, PDE: 2.268179e-05, BC: 4.004190e-09, IC: 1.457539e-07
# LBFGS外循环 76/500, 当前损失: 2.404334e-05
# LBFGS外循环 77/500, 当前损失: 2.378574e-05
# LBFGS外循环 78/500, 当前损失: 2.351202e-05
# LBFGS外循环 79/500, 当前损失: 2.328589e-05
# LBFGS Iter: 6800, Loss: 2.298266e-05, PDE: 2.163752e-05, BC: 7.089935e-09, IC: 1.274244e-07
# LBFGS外循环 80/500, 当前损失: 2.292756e-05
# LBFGS外循环 81/500, 当前损失: 2.267043e-05
# LBFGS外循环 82/500, 当前损失: 2.254569e-05
# LBFGS外循环 83/500, 当前损失: 2.235502e-05
# LBFGS外循环 84/500, 当前损失: 2.216046e-05
# LBFGS Iter: 6900, Loss: 2.210347e-05, PDE: 2.062320e-05, BC: 3.785122e-09, IC: 1.442420e-07
# LBFGS外循环 85/500, 当前损失: 2.196003e-05
# LBFGS外循环 86/500, 当前损失: 2.176840e-05
# LBFGS外循环 87/500, 当前损失: 2.151388e-05
# LBFGS外循环 88/500, 当前损失: 2.134093e-05
# LBFGS Iter: 7000, Loss: 2.117954e-05, PDE: 2.000789e-05, BC: 2.283578e-09, IC: 1.148813e-07
# LBFGS外循环 89/500, 当前损失: 2.112117e-05
# LBFGS外循环 90/500, 当前损失: 2.083416e-05
# LBFGS外循环 91/500, 当前损失: 2.064789e-05
# LBFGS外循环 92/500, 当前损失: 2.044020e-05
# LBFGS外循环 93/500, 当前损失: 2.030880e-05
# LBFGS Iter: 7100, Loss: 2.026940e-05, PDE: 1.932920e-05, BC: 2.645500e-09, IC: 9.137483e-08
# LBFGS外循环 94/500, 当前损失: 2.018650e-05
# LBFGS外循环 95/500, 当前损失: 1.998154e-05
# LBFGS外循环 96/500, 当前损失: 1.986665e-05
# LBFGS外循环 97/500, 当前损失: 1.966068e-05
# LBFGS Iter: 7200, Loss: 1.950408e-05, PDE: 1.852299e-05, BC: 4.075418e-09, IC: 9.403352e-08
# LBFGS外循环 98/500, 当前损失: 1.946725e-05
# LBFGS外循环 99/500, 当前损失: 1.924022e-05
# LBFGS外循环 100/500, 当前损失: 1.915401e-05
# LBFGS外循环 101/500, 当前损失: 1.903137e-05
# LBFGS外循环 102/500, 当前损失: 1.891204e-05
# LBFGS Iter: 7300, Loss: 1.890121e-05, PDE: 1.802520e-05, BC: 3.083544e-09, IC: 8.451809e-08
# LBFGS外循环 103/500, 当前损失: 1.880004e-05
# LBFGS外循环 104/500, 当前损失: 1.861046e-05
# LBFGS外循环 105/500, 当前损失: 1.846336e-05
# LBFGS外循环 106/500, 当前损失: 1.825311e-05
# LBFGS Iter: 7400, Loss: 1.819799e-05, PDE: 1.730392e-05, BC: 3.298328e-09, IC: 8.610955e-08
# LBFGS外循环 107/500, 当前损失: 1.817782e-05
# LBFGS外循环 108/500, 当前损失: 1.803679e-05
# LBFGS外循环 109/500, 当前损失: 1.797347e-05
# LBFGS外循环 110/500, 当前损失: 1.789879e-05
# LBFGS外循环 111/500, 当前损失: 1.777448e-05
# LBFGS Iter: 7500, Loss: 1.776331e-05, PDE: 1.691649e-05, BC: 2.072646e-09, IC: 8.260941e-08
# LBFGS外循环 112/500, 当前损失: 1.759968e-05
# LBFGS外循环 113/500, 当前损失: 1.750163e-05
# LBFGS外循环 114/500, 当前损失: 1.737961e-05
# LBFGS外循环 115/500, 当前损失: 1.729995e-05
# LBFGS Iter: 7600, Loss: 1.723867e-05, PDE: 1.629114e-05, BC: 5.386620e-09, IC: 8.936637e-08
# LBFGS外循环 116/500, 当前损失: 1.720274e-05
# LBFGS外循环 117/500, 当前损失: 1.713194e-05
# LBFGS外循环 118/500, 当前损失: 1.703508e-05
# LBFGS外循环 119/500, 当前损失: 1.690459e-05
# LBFGS外循环 120/500, 当前损失: 1.682144e-05
# LBFGS Iter: 7700, Loss: 1.682144e-05, PDE: 1.583649e-05, BC: 7.615159e-09, IC: 9.087981e-08
# LBFGS外循环 121/500, 当前损失: 1.669771e-05
# LBFGS外循环 122/500, 当前损失: 1.655581e-05
# LBFGS外循环 123/500, 当前损失: 1.647977e-05
# LBFGS外循环 124/500, 当前损失: 1.642329e-05
# LBFGS Iter: 7800, Loss: 1.639642e-05, PDE: 1.546310e-05, BC: 5.582539e-09, IC: 8.774974e-08
# LBFGS外循环 125/500, 当前损失: 1.638062e-05
# LBFGS外循环 126/500, 当前损失: 1.633248e-05
# LBFGS外循环 127/500, 当前损失: 1.626754e-05
# LBFGS外循环 128/500, 当前损失: 1.620166e-05
# LBFGS Iter: 7900, Loss: 1.616519e-05, PDE: 1.536647e-05, BC: 3.816421e-09, IC: 7.605570e-08
# LBFGS外循环 129/500, 当前损失: 1.616046e-05
# LBFGS外循环 130/500, 当前损失: 1.612733e-05
# LBFGS外循环 131/500, 当前损失: 1.604699e-05
# LBFGS外循环 132/500, 当前损失: 1.598056e-05
# LBFGS外循环 133/500, 当前损失: 1.593754e-05
# LBFGS Iter: 8000, Loss: 1.592391e-05, PDE: 1.513137e-05, BC: 4.360380e-09, IC: 7.489432e-08
# LBFGS外循环 134/500, 当前损失: 1.585322e-05
# LBFGS外循环 135/500, 当前损失: 1.578984e-05
# LBFGS外循环 136/500, 当前损失: 1.569284e-05
# LBFGS外循环 137/500, 当前损失: 1.558579e-05
# LBFGS Iter: 8100, Loss: 1.555955e-05, PDE: 1.496176e-05, BC: 4.436473e-09, IC: 5.534168e-08
# LBFGS外循环 138/500, 当前损失: 1.555076e-05
# LBFGS外循环 139/500, 当前损失: 1.548004e-05
# LBFGS外循环 140/500, 当前损失: 1.543895e-05
# LBFGS外循环 141/500, 当前损失: 1.538903e-05
# LBFGS外循环 142/500, 当前损失: 1.532500e-05
# LBFGS Iter: 8200, Loss: 1.531201e-05, PDE: 1.467063e-05, BC: 4.701335e-09, IC: 5.943618e-08
# LBFGS外循环 143/500, 当前损失: 1.525676e-05
# LBFGS外循环 144/500, 当前损失: 1.515307e-05
# LBFGS外循环 145/500, 当前损失: 1.509522e-05
# LBFGS外循环 146/500, 当前损失: 1.505480e-05
# LBFGS Iter: 8300, Loss: 1.501217e-05, PDE: 1.437726e-05, BC: 4.011855e-09, IC: 5.947951e-08
# LBFGS外循环 147/500, 当前损失: 1.500684e-05
# LBFGS外循环 148/500, 当前损失: 1.488498e-05
# LBFGS外循环 149/500, 当前损失: 1.485292e-05
# LBFGS外循环 150/500, 当前损失: 1.478529e-05
# LBFGS外循环 151/500, 当前损失: 1.471585e-05
# LBFGS Iter: 8400, Loss: 1.466271e-05, PDE: 1.408218e-05, BC: 3.520306e-09, IC: 5.453238e-08
# LBFGS外循环 152/500, 当前损失: 1.458098e-05
# LBFGS外循环 153/500, 当前损失: 1.449864e-05
# LBFGS外循环 154/500, 当前损失: 1.442987e-05
# LBFGS外循环 155/500, 当前损失: 1.440140e-05
# LBFGS Iter: 8500, Loss: 1.436521e-05, PDE: 1.388898e-05, BC: 2.386446e-09, IC: 4.523598e-08
# LBFGS外循环 156/500, 当前损失: 1.435373e-05
# LBFGS外循环 157/500, 当前损失: 1.432918e-05
# LBFGS外循环 158/500, 当前损失: 1.427854e-05
# LBFGS外循环 159/500, 当前损失: 1.420060e-05
# LBFGS外循环 160/500, 当前损失: 1.414058e-05
# LBFGS Iter: 8600, Loss: 1.414197e-05, PDE: 1.367856e-05, BC: 2.363238e-09, IC: 4.397708e-08
# LBFGS外循环 161/500, 当前损失: 1.410196e-05
# LBFGS外循环 162/500, 当前损失: 1.402667e-05
# LBFGS外循环 163/500, 当前损失: 1.396723e-05
# LBFGS外循环 164/500, 当前损失: 1.380447e-05
# LBFGS Iter: 8700, Loss: 1.370701e-05, PDE: 1.316339e-05, BC: 7.141738e-09, IC: 4.722120e-08
# LBFGS外循环 165/500, 当前损失: 1.367848e-05
# LBFGS外循环 166/500, 当前损失: 1.359787e-05
# LBFGS外循环 167/500, 当前损失: 1.354844e-05
# LBFGS外循环 168/500, 当前损失: 1.348708e-05
# LBFGS外循环 169/500, 当前损失: 1.346317e-05
# LBFGS Iter: 8800, Loss: 1.346006e-05, PDE: 1.288298e-05, BC: 8.413169e-09, IC: 4.929541e-08
# LBFGS外循环 170/500, 当前损失: 1.340836e-05
# LBFGS外循环 171/500, 当前损失: 1.337269e-05
# LBFGS外循环 172/500, 当前损失: 1.331295e-05
# LBFGS外循环 173/500, 当前损失: 1.325888e-05
# LBFGS Iter: 8900, Loss: 1.322949e-05, PDE: 1.269590e-05, BC: 6.332829e-09, IC: 4.702635e-08
# LBFGS外循环 174/500, 当前损失: 1.321193e-05
# LBFGS外循环 175/500, 当前损失: 1.315764e-05
# LBFGS外循环 176/500, 当前损失: 1.311986e-05
# LBFGS外循环 177/500, 当前损失: 1.309015e-05
# LBFGS Iter: 9000, Loss: 1.305840e-05, PDE: 1.254812e-05, BC: 4.290632e-09, IC: 4.673718e-08
# LBFGS外循环 178/500, 当前损失: 1.305724e-05
# LBFGS外循环 179/500, 当前损失: 1.302553e-05
# LBFGS外循环 180/500, 当前损失: 1.298187e-05
# LBFGS外循环 181/500, 当前损失: 1.292930e-05
# LBFGS外循环 182/500, 当前损失: 1.287676e-05
# LBFGS Iter: 9100, Loss: 1.286574e-05, PDE: 1.239409e-05, BC: 3.194526e-09, IC: 4.397082e-08
# LBFGS外循环 183/500, 当前损失: 1.284276e-05
# LBFGS外循环 184/500, 当前损失: 1.281899e-05
# LBFGS外循环 185/500, 当前损失: 1.275454e-05
# LBFGS外循环 186/500, 当前损失: 1.270618e-05
# LBFGS Iter: 9200, Loss: 1.266132e-05, PDE: 1.223318e-05, BC: 3.064267e-09, IC: 3.974949e-08
# LBFGS外循环 187/500, 当前损失: 1.265860e-05
# LBFGS外循环 188/500, 当前损失: 1.262794e-05
# LBFGS外循环 189/500, 当前损失: 1.260598e-05
# LBFGS外循环 190/500, 当前损失: 1.258769e-05
# LBFGS外循环 191/500, 当前损失: 1.256990e-05
# LBFGS Iter: 9300, Loss: 1.256169e-05, PDE: 1.211587e-05, BC: 3.224269e-09, IC: 4.135696e-08
# LBFGS外循环 192/500, 当前损失: 1.253568e-05
# LBFGS外循环 193/500, 当前损失: 1.251351e-05
# LBFGS外循环 194/500, 当前损失: 1.247730e-05
# LBFGS外循环 195/500, 当前损失: 1.244053e-05
# LBFGS Iter: 9400, Loss: 1.240980e-05, PDE: 1.200397e-05, BC: 2.663898e-09, IC: 3.791958e-08
# LBFGS外循环 196/500, 当前损失: 1.240620e-05
# LBFGS外循环 197/500, 当前损失: 1.237339e-05
# LBFGS外循环 198/500, 当前损失: 1.234179e-05
# LBFGS外循环 199/500, 当前损失: 1.230184e-05
# LBFGS外循环 200/500, 当前损失: 1.226788e-05
# LBFGS Iter: 9500, Loss: 1.225622e-05, PDE: 1.189000e-05, BC: 2.761009e-09, IC: 3.386116e-08
# LBFGS外循环 201/500, 当前损失: 1.223207e-05
# LBFGS外循环 202/500, 当前损失: 1.217217e-05
# LBFGS外循环 203/500, 当前损失: 1.213099e-05
# LBFGS外循环 204/500, 当前损失: 1.211073e-05
# LBFGS Iter: 9600, Loss: 1.208993e-05, PDE: 1.164709e-05, BC: 4.291268e-09, IC: 3.999233e-08
# LBFGS外循环 205/500, 当前损失: 1.208567e-05
# LBFGS外循环 206/500, 当前损失: 1.206670e-05
# LBFGS外循环 207/500, 当前损失: 1.199639e-05
# LBFGS外循环 208/500, 当前损失: 1.195501e-05
# LBFGS外循环 209/500, 当前损失: 1.192796e-05
# LBFGS Iter: 9700, Loss: 1.192346e-05, PDE: 1.151568e-05, BC: 4.213834e-09, IC: 3.656412e-08
# LBFGS外循环 210/500, 当前损失: 1.190746e-05
# LBFGS外循环 211/500, 当前损失: 1.188827e-05
# LBFGS外循环 212/500, 当前损失: 1.184621e-05
# LBFGS外循环 213/500, 当前损失: 1.181491e-05
# LBFGS Iter: 9800, Loss: 1.179111e-05, PDE: 1.137818e-05, BC: 3.400412e-09, IC: 3.789230e-08
# LBFGS外循环 214/500, 当前损失: 1.178292e-05
# LBFGS外循环 215/500, 当前损失: 1.175055e-05
# LBFGS外循环 216/500, 当前损失: 1.172897e-05
# LBFGS外循环 217/500, 当前损失: 1.170078e-05
# LBFGS外循环 218/500, 当前损失: 1.168730e-05
# LBFGS Iter: 9900, Loss: 1.169346e-05, PDE: 1.131873e-05, BC: 2.533988e-09, IC: 3.493921e-08
# LBFGS外循环 219/500, 当前损失: 1.166655e-05
# LBFGS外循环 220/500, 当前损失: 1.164964e-05
# LBFGS外循环 221/500, 当前损失: 1.161419e-05
# LBFGS外循环 222/500, 当前损失: 1.157996e-05
# LBFGS Iter: 10000, Loss: 1.157263e-05, PDE: 1.121949e-05, BC: 2.258255e-09, IC: 3.305549e-08
# LBFGS外循环 223/500, 当前损失: 1.156364e-05
# LBFGS外循环 224/500, 当前损失: 1.154967e-05
# LBFGS外循环 225/500, 当前损失: 1.153170e-05
# LBFGS外循环 226/500, 当前损失: 1.149671e-05
# LBFGS Iter: 10100, Loss: 1.147450e-05, PDE: 1.113814e-05, BC: 2.456037e-09, IC: 3.118006e-08
# LBFGS外循环 227/500, 当前损失: 1.147450e-05
# LBFGS外循环 228/500, 当前损失: 1.145745e-05
# LBFGS外循环 229/500, 当前损失: 1.142628e-05
# LBFGS外循环 230/500, 当前损失: 1.140400e-05
# LBFGS外循环 231/500, 当前损失: 1.137431e-05
# LBFGS Iter: 10200, Loss: 1.136997e-05, PDE: 1.103032e-05, BC: 2.437372e-09, IC: 3.152774e-08
# LBFGS外循环 232/500, 当前损失: 1.135807e-05
# LBFGS外循环 233/500, 当前损失: 1.131710e-05
# LBFGS外循环 234/500, 当前损失: 1.129059e-05
# LBFGS外循环 235/500, 当前损失: 1.125793e-05
# LBFGS Iter: 10300, Loss: 1.123992e-05, PDE: 1.087827e-05, BC: 2.162507e-09, IC: 3.400259e-08
# LBFGS外循环 236/500, 当前损失: 1.123949e-05
# LBFGS外循环 237/500, 当前损失: 1.121501e-05
# LBFGS外循环 238/500, 当前损失: 1.119394e-05
# LBFGS外循环 239/500, 当前损失: 1.116559e-05
# LBFGS外循环 240/500, 当前损失: 1.114289e-05
# LBFGS Iter: 10400, Loss: 1.113219e-05, PDE: 1.076643e-05, BC: 2.255267e-09, IC: 3.432049e-08
# LBFGS外循环 241/500, 当前损失: 1.111461e-05
# LBFGS外循环 242/500, 当前损失: 1.108627e-05
# LBFGS外循环 243/500, 当前损失: 1.104625e-05
# LBFGS外循环 244/500, 当前损失: 1.101626e-05
# LBFGS Iter: 10500, Loss: 1.100230e-05, PDE: 1.063777e-05, BC: 1.967333e-09, IC: 3.448586e-08
# LBFGS外循环 245/500, 当前损失: 1.100028e-05
# LBFGS外循环 246/500, 当前损失: 1.096761e-05
# LBFGS外循环 247/500, 当前损失: 1.094460e-05
# LBFGS外循环 248/500, 当前损失: 1.092462e-05
# LBFGS外循环 249/500, 当前损失: 1.090181e-05
# LBFGS Iter: 10600, Loss: 1.089024e-05, PDE: 1.053836e-05, BC: 2.417886e-09, IC: 3.276953e-08
# LBFGS外循环 250/500, 当前损失: 1.087193e-05
# LBFGS外循环 251/500, 当前损失: 1.085822e-05
# LBFGS外循环 252/500, 当前损失: 1.085415e-05
# LBFGS外循环 253/500, 当前损失: 1.083451e-05
# LBFGS Iter: 10700, Loss: 1.081766e-05, PDE: 1.046463e-05, BC: 2.502284e-09, IC: 3.280061e-08
# LBFGS外循环 254/500, 当前损失: 1.079617e-05
# LBFGS外循环 255/500, 当前损失: 1.077612e-05
# LBFGS外循环 256/500, 当前损失: 1.074984e-05
# LBFGS外循环 257/500, 当前损失: 1.072139e-05
# LBFGS Iter: 10800, Loss: 1.069060e-05, PDE: 1.039179e-05, BC: 2.150872e-09, IC: 2.773068e-08
# LBFGS外循环 258/500, 当前损失: 1.069060e-05
# LBFGS外循环 259/500, 当前损失: 1.066983e-05
# LBFGS外循环 260/500, 当前损失: 1.065632e-05
# LBFGS外循环 261/500, 当前损失: 1.064274e-05
# LBFGS外循环 262/500, 当前损失: 1.062360e-05
# LBFGS Iter: 10900, Loss: 1.061436e-05, PDE: 1.032061e-05, BC: 1.980573e-09, IC: 2.739377e-08
# LBFGS外循环 263/500, 当前损失: 1.060874e-05
# LBFGS外循环 264/500, 当前损失: 1.059413e-05
# LBFGS外循环 265/500, 当前损失: 1.057388e-05
# LBFGS外循环 266/500, 当前损失: 1.055084e-05
# LBFGS Iter: 11000, Loss: 1.053404e-05, PDE: 1.024413e-05, BC: 2.734747e-09, IC: 2.625571e-08
# LBFGS外循环 267/500, 当前损失: 1.053247e-05
# LBFGS外循环 268/500, 当前损失: 1.051157e-05
# LBFGS外循环 269/500, 当前损失: 1.048989e-05
# LBFGS外循环 270/500, 当前损失: 1.046798e-05
# LBFGS外循环 271/500, 当前损失: 1.045104e-05
# LBFGS Iter: 11100, Loss: 1.043998e-05, PDE: 1.016205e-05, BC: 2.070053e-09, IC: 2.572296e-08
# LBFGS外循环 272/500, 当前损失: 1.042217e-05
# LBFGS外循环 273/500, 当前损失: 1.040236e-05
# LBFGS外循环 274/500, 当前损失: 1.037749e-05
# LBFGS外循环 275/500, 当前损失: 1.035544e-05
# LBFGS Iter: 11200, Loss: 1.033751e-05, PDE: 1.007783e-05, BC: 1.968230e-09, IC: 2.399948e-08
# LBFGS外循环 276/500, 当前损失: 1.033543e-05
# LBFGS外循环 277/500, 当前损失: 1.030048e-05
# LBFGS外循环 278/500, 当前损失: 1.029032e-05
# LBFGS外循环 279/500, 当前损失: 1.027880e-05
# LBFGS外循环 280/500, 当前损失: 1.025354e-05
# LBFGS Iter: 11300, Loss: 1.024880e-05, PDE: 1.000014e-05, BC: 1.876431e-09, IC: 2.298975e-08
# LBFGS外循环 281/500, 当前损失: 1.023693e-05
# LBFGS外循环 282/500, 当前损失: 1.020994e-05
# LBFGS外循环 283/500, 当前损失: 1.019177e-05
# LBFGS外循环 284/500, 当前损失: 1.018272e-05
# LBFGS Iter: 11400, Loss: 1.017909e-05, PDE: 9.933499e-06, BC: 1.794217e-09, IC: 2.276487e-08
# LBFGS外循环 285/500, 当前损失: 1.017884e-05
# LBFGS外循环 286/500, 当前损失: 1.017884e-05
# LBFGS外循环 287/500, 当前损失: 1.017884e-05
# LBFGS外循环 288/500, 当前损失: 1.017884e-05
# LBFGS外循环 289/500, 当前损失: 1.017884e-05
# LBFGS外循环 290/500, 当前损失: 1.017884e-05
# LBFGS外循环 291/500, 当前损失: 1.017884e-05
# LBFGS外循环 292/500, 当前损失: 1.017884e-05
# LBFGS外循环 293/500, 当前损失: 1.017884e-05
# LBFGS外循环 294/500, 当前损失: 1.017884e-05
# LBFGS外循环 295/500, 当前损失: 1.017884e-05
# LBFGS外循环 296/500, 当前损失: 1.017884e-05
# LBFGS外循环 297/500, 当前损失: 1.017884e-05
# LBFGS Iter: 11500, Loss: 1.017889e-05, PDE: 9.933751e-06, BC: 1.794610e-09, IC: 2.271926e-08
# LBFGS外循环 298/500, 当前损失: 1.017884e-05
# LBFGS外循环 299/500, 当前损失: 1.017884e-05
# LBFGS外循环 300/500, 当前损失: 1.017884e-05
# LBFGS外循环 301/500, 当前损失: 1.017884e-05
# LBFGS外循环 302/500, 当前损失: 1.017884e-05
# LBFGS外循环 303/500, 当前损失: 1.017884e-05
# LBFGS外循环 304/500, 当前损失: 1.017884e-05
# LBFGS外循环 305/500, 当前损失: 1.017884e-05
# LBFGS外循环 306/500, 当前损失: 1.017884e-05
# LBFGS外循环 307/500, 当前损失: 1.017884e-05
# LBFGS外循环 308/500, 当前损失: 1.017884e-05
# LBFGS外循环 309/500, 当前损失: 1.017884e-05
# LBFGS外循环 310/500, 当前损失: 1.017884e-05
# LBFGS外循环 311/500, 当前损失: 1.017884e-05
# LBFGS Iter: 11600, Loss: 1.017884e-05, PDE: 9.933742e-06, BC: 1.794750e-09, IC: 2.271549e-08
# LBFGS外循环 312/500, 当前损失: 1.017884e-05
# LBFGS外循环 313/500, 当前损失: 1.017884e-05
# LBFGS外循环 314/500, 当前损失: 1.017884e-05
# LBFGS外循环 315/500, 当前损失: 1.017884e-05
# LBFGS外循环 316/500, 当前损失: 1.017884e-05
# LBFGS外循环 317/500, 当前损失: 1.017884e-05
# LBFGS外循环 318/500, 当前损失: 1.017884e-05
# LBFGS外循环 319/500, 当前损失: 1.017884e-05
# LBFGS外循环 320/500, 当前损失: 1.017884e-05
# LBFGS外循环 321/500, 当前损失: 1.017884e-05
# LBFGS外循环 322/500, 当前损失: 1.017884e-05
# LBFGS外循环 323/500, 当前损失: 1.017884e-05
# LBFGS外循环 324/500, 当前损失: 1.017884e-05
# LBFGS外循环 325/500, 当前损失: 1.017884e-05
# LBFGS Iter: 11700, Loss: 1.017884e-05, PDE: 9.933740e-06, BC: 1.794750e-09, IC: 2.271547e-08
# LBFGS外循环 326/500, 当前损失: 1.017884e-05
# LBFGS外循环 327/500, 当前损失: 1.017884e-05
# LBFGS外循环 328/500, 当前损失: 1.017884e-05
# LBFGS外循环 329/500, 当前损失: 1.017884e-05
# LBFGS外循环 330/500, 当前损失: 1.017884e-05
# LBFGS外循环 331/500, 当前损失: 1.017884e-05
# LBFGS外循环 332/500, 当前损失: 1.017884e-05
# LBFGS外循环 333/500, 当前损失: 1.017884e-05
# LBFGS外循环 334/500, 当前损失: 1.017884e-05
# LBFGS外循环 335/500, 当前损失: 1.017884e-05
# LBFGS外循环 336/500, 当前损失: 1.017884e-05
# LBFGS外循环 337/500, 当前损失: 1.017884e-05
# LBFGS外循环 338/500, 当前损失: 1.017884e-05
# LBFGS外循环 339/500, 当前损失: 1.017884e-05
# LBFGS外循环 340/500, 当前损失: 1.017884e-05
# LBFGS Iter: 11800, Loss: 1.017885e-05, PDE: 9.933775e-06, BC: 1.793795e-09, IC: 2.271380e-08
# LBFGS外循环 341/500, 当前损失: 1.017884e-05
# LBFGS外循环 342/500, 当前损失: 1.017884e-05
# LBFGS外循环 343/500, 当前损失: 1.017884e-05
# LBFGS外循环 344/500, 当前损失: 1.017884e-05
# LBFGS外循环 345/500, 当前损失: 1.017884e-05
# LBFGS外循环 346/500, 当前损失: 1.017884e-05
# LBFGS外循环 347/500, 当前损失: 1.017884e-05
# LBFGS外循环 348/500, 当前损失: 1.017884e-05
# LBFGS外循环 349/500, 当前损失: 1.017884e-05
# LBFGS外循环 350/500, 当前损失: 1.017884e-05
# LBFGS外循环 351/500, 当前损失: 1.017884e-05
# LBFGS外循环 352/500, 当前损失: 1.017884e-05
# LBFGS外循环 353/500, 当前损失: 1.017884e-05
# LBFGS外循环 354/500, 当前损失: 1.017884e-05
# LBFGS Iter: 11900, Loss: 1.017885e-05, PDE: 9.933748e-06, BC: 1.794748e-09, IC: 2.271598e-08
# LBFGS外循环 355/500, 当前损失: 1.017884e-05
# LBFGS外循环 356/500, 当前损失: 1.017884e-05
# LBFGS外循环 357/500, 当前损失: 1.017884e-05
# LBFGS外循环 358/500, 当前损失: 1.017884e-05
# LBFGS外循环 359/500, 当前损失: 1.017884e-05
# LBFGS外循环 360/500, 当前损失: 1.017884e-05
# LBFGS外循环 361/500, 当前损失: 1.017884e-05
# LBFGS外循环 362/500, 当前损失: 1.017884e-05
# LBFGS外循环 363/500, 当前损失: 1.017884e-05
# LBFGS外循环 364/500, 当前损失: 1.017884e-05
# LBFGS外循环 365/500, 当前损失: 1.017884e-05
# LBFGS外循环 366/500, 当前损失: 1.017884e-05
# LBFGS外循环 367/500, 当前损失: 1.017884e-05
# LBFGS外循环 368/500, 当前损失: 1.017884e-05
# LBFGS Iter: 12000, Loss: 1.017884e-05, PDE: 9.933740e-06, BC: 1.794750e-09, IC: 2.271547e-08
# LBFGS外循环 369/500, 当前损失: 1.017884e-05
# LBFGS外循环 370/500, 当前损失: 1.017884e-05
# LBFGS外循环 371/500, 当前损失: 1.017884e-05
# LBFGS外循环 372/500, 当前损失: 1.017884e-05
# LBFGS外循环 373/500, 当前损失: 1.017884e-05
# LBFGS外循环 374/500, 当前损失: 1.017884e-05
# LBFGS外循环 375/500, 当前损失: 1.017884e-05
# LBFGS外循环 376/500, 当前损失: 1.017884e-05
# LBFGS外循环 377/500, 当前损失: 1.017884e-05
# LBFGS外循环 378/500, 当前损失: 1.017884e-05
# LBFGS外循环 379/500, 当前损失: 1.017884e-05
# LBFGS外循环 380/500, 当前损失: 1.017884e-05
# LBFGS外循环 381/500, 当前损失: 1.017884e-05
# LBFGS外循环 382/500, 当前损失: 1.017884e-05
# LBFGS外循环 383/500, 当前损失: 1.017884e-05
# LBFGS Iter: 12100, Loss: 1.017884e-05, PDE: 9.933740e-06, BC: 1.794750e-09, IC: 2.271547e-08
# LBFGS外循环 384/500, 当前损失: 1.017884e-05
# LBFGS外循环 385/500, 当前损失: 1.017884e-05
# LBFGS外循环 386/500, 当前损失: 1.017884e-05
# LBFGS外循环 387/500, 当前损失: 1.017884e-05
# LBFGS外循环 388/500, 当前损失: 1.017884e-05
# LBFGS外循环 389/500, 当前损失: 1.017884e-05
# LBFGS外循环 390/500, 当前损失: 1.017884e-05
# LBFGS外循环 391/500, 当前损失: 1.017884e-05
# LBFGS外循环 392/500, 当前损失: 1.017884e-05
# LBFGS外循环 393/500, 当前损失: 1.017884e-05
# LBFGS外循环 394/500, 当前损失: 1.017884e-05
# LBFGS外循环 395/500, 当前损失: 1.017884e-05
# LBFGS外循环 396/500, 当前损失: 1.017884e-05
# LBFGS外循环 397/500, 当前损失: 1.017884e-05
# LBFGS Iter: 12200, Loss: 1.017889e-05, PDE: 9.933751e-06, BC: 1.794610e-09, IC: 2.271926e-08
# LBFGS外循环 398/500, 当前损失: 1.017884e-05
# LBFGS外循环 399/500, 当前损失: 1.017884e-05
# LBFGS外循环 400/500, 当前损失: 1.017884e-05
# LBFGS外循环 401/500, 当前损失: 1.017884e-05
# LBFGS外循环 402/500, 当前损失: 1.017884e-05
# LBFGS外循环 403/500, 当前损失: 1.017884e-05
# LBFGS外循环 404/500, 当前损失: 1.017884e-05
# LBFGS外循环 405/500, 当前损失: 1.017884e-05
# LBFGS外循环 406/500, 当前损失: 1.017884e-05
# LBFGS外循环 407/500, 当前损失: 1.017884e-05
# LBFGS外循环 408/500, 当前损失: 1.017884e-05
# LBFGS外循环 409/500, 当前损失: 1.017884e-05
# LBFGS外循环 410/500, 当前损失: 1.017884e-05
# LBFGS外循环 411/500, 当前损失: 1.017884e-05
# LBFGS Iter: 12300, Loss: 1.017884e-05, PDE: 9.933742e-06, BC: 1.794750e-09, IC: 2.271549e-08
# LBFGS外循环 412/500, 当前损失: 1.017884e-05
# LBFGS外循环 413/500, 当前损失: 1.017884e-05
# LBFGS外循环 414/500, 当前损失: 1.017884e-05
# LBFGS外循环 415/500, 当前损失: 1.017884e-05
# LBFGS外循环 416/500, 当前损失: 1.017884e-05
# LBFGS外循环 417/500, 当前损失: 1.017884e-05
# LBFGS外循环 418/500, 当前损失: 1.017884e-05
# LBFGS外循环 419/500, 当前损失: 1.017884e-05
# LBFGS外循环 420/500, 当前损失: 1.017884e-05
# LBFGS外循环 421/500, 当前损失: 1.017884e-05
# LBFGS外循环 422/500, 当前损失: 1.017884e-05
# LBFGS外循环 423/500, 当前损失: 1.017884e-05
# LBFGS外循环 424/500, 当前损失: 1.017884e-05
# LBFGS外循环 425/500, 当前损失: 1.017884e-05
# LBFGS Iter: 12400, Loss: 1.017884e-05, PDE: 9.933740e-06, BC: 1.794750e-09, IC: 2.271547e-08
# LBFGS外循环 426/500, 当前损失: 1.017884e-05
# LBFGS外循环 427/500, 当前损失: 1.017884e-05
# LBFGS外循环 428/500, 当前损失: 1.017884e-05
# LBFGS外循环 429/500, 当前损失: 1.017884e-05
# LBFGS外循环 430/500, 当前损失: 1.017884e-05
# LBFGS外循环 431/500, 当前损失: 1.017884e-05
# LBFGS外循环 432/500, 当前损失: 1.017884e-05
# LBFGS外循环 433/500, 当前损失: 1.017884e-05
# LBFGS外循环 434/500, 当前损失: 1.017884e-05
# LBFGS外循环 435/500, 当前损失: 1.017884e-05
# LBFGS外循环 436/500, 当前损失: 1.017884e-05
# LBFGS外循环 437/500, 当前损失: 1.017884e-05
# LBFGS外循环 438/500, 当前损失: 1.017884e-05
# LBFGS外循环 439/500, 当前损失: 1.017884e-05
# LBFGS外循环 440/500, 当前损失: 1.017884e-05
# LBFGS Iter: 12500, Loss: 1.017885e-05, PDE: 9.933775e-06, BC: 1.793795e-09, IC: 2.271380e-08
# LBFGS外循环 441/500, 当前损失: 1.017884e-05
# LBFGS外循环 442/500, 当前损失: 1.017884e-05
# LBFGS外循环 443/500, 当前损失: 1.017884e-05
# LBFGS外循环 444/500, 当前损失: 1.017884e-05
# LBFGS外循环 445/500, 当前损失: 1.017884e-05
# LBFGS外循环 446/500, 当前损失: 1.017884e-05
# LBFGS外循环 447/500, 当前损失: 1.017884e-05
# LBFGS外循环 448/500, 当前损失: 1.017884e-05
# LBFGS外循环 449/500, 当前损失: 1.017884e-05
# LBFGS外循环 450/500, 当前损失: 1.017884e-05
# LBFGS外循环 451/500, 当前损失: 1.017884e-05
# LBFGS外循环 452/500, 当前损失: 1.017884e-05
# LBFGS外循环 453/500, 当前损失: 1.017884e-05
# LBFGS外循环 454/500, 当前损失: 1.017884e-05
# LBFGS Iter: 12600, Loss: 1.017885e-05, PDE: 9.933748e-06, BC: 1.794748e-09, IC: 2.271598e-08
# LBFGS外循环 455/500, 当前损失: 1.017884e-05
# LBFGS外循环 456/500, 当前损失: 1.017884e-05
# LBFGS外循环 457/500, 当前损失: 1.017884e-05
# LBFGS外循环 458/500, 当前损失: 1.017884e-05
# LBFGS外循环 459/500, 当前损失: 1.017884e-05
# LBFGS外循环 460/500, 当前损失: 1.017884e-05
# LBFGS外循环 461/500, 当前损失: 1.017884e-05
# LBFGS外循环 462/500, 当前损失: 1.017884e-05
# LBFGS外循环 463/500, 当前损失: 1.017884e-05
# LBFGS外循环 464/500, 当前损失: 1.017884e-05
# LBFGS外循环 465/500, 当前损失: 1.017884e-05
# LBFGS外循环 466/500, 当前损失: 1.017884e-05
# LBFGS外循环 467/500, 当前损失: 1.017884e-05
# LBFGS外循环 468/500, 当前损失: 1.017884e-05
# LBFGS Iter: 12700, Loss: 1.017884e-05, PDE: 9.933740e-06, BC: 1.794750e-09, IC: 2.271547e-08
# LBFGS外循环 469/500, 当前损失: 1.017884e-05
# LBFGS外循环 470/500, 当前损失: 1.017884e-05
# LBFGS外循环 471/500, 当前损失: 1.017884e-05
# LBFGS外循环 472/500, 当前损失: 1.017884e-05
# LBFGS外循环 473/500, 当前损失: 1.017884e-05
# LBFGS外循环 474/500, 当前损失: 1.017884e-05
# LBFGS外循环 475/500, 当前损失: 1.017884e-05
# LBFGS外循环 476/500, 当前损失: 1.017884e-05
# LBFGS外循环 477/500, 当前损失: 1.017884e-05
# LBFGS外循环 478/500, 当前损失: 1.017884e-05
# LBFGS外循环 479/500, 当前损失: 1.017884e-05
# LBFGS外循环 480/500, 当前损失: 1.017884e-05
# LBFGS外循环 481/500, 当前损失: 1.017884e-05
# LBFGS外循环 482/500, 当前损失: 1.017884e-05
# LBFGS外循环 483/500, 当前损失: 1.017884e-05
# LBFGS Iter: 12800, Loss: 1.017884e-05, PDE: 9.933740e-06, BC: 1.794750e-09, IC: 2.271547e-08
# LBFGS外循环 484/500, 当前损失: 1.017884e-05
# LBFGS外循环 485/500, 当前损失: 1.017884e-05
# LBFGS外循环 486/500, 当前损失: 1.017884e-05
# LBFGS外循环 487/500, 当前损失: 1.017884e-05
# LBFGS外循环 488/500, 当前损失: 1.017884e-05
# LBFGS外循环 489/500, 当前损失: 1.017884e-05
# LBFGS外循环 490/500, 当前损失: 1.017884e-05
# LBFGS外循环 491/500, 当前损失: 1.017884e-05
# LBFGS外循环 492/500, 当前损失: 1.017884e-05
# LBFGS外循环 493/500, 当前损失: 1.017884e-05
# LBFGS外循环 494/500, 当前损失: 1.017884e-05
# LBFGS外循环 495/500, 当前损失: 1.017884e-05
# LBFGS外循环 496/500, 当前损失: 1.017884e-05
# LBFGS外循环 497/500, 当前损失: 1.017884e-05
# LBFGS Iter: 12900, Loss: 1.017889e-05, PDE: 9.933751e-06, BC: 1.794610e-09, IC: 2.271926e-08
# LBFGS外循环 498/500, 当前损失: 1.017884e-05
# LBFGS外循环 499/500, 当前损失: 1.017884e-05
# LBFGS外循环 500/500, 当前损失: 1.017884e-05
# 优化完成!

# %%
# 修改可视化部分 - 更新网格范围到[0, 10]
# 创建网格点
nx, nt = 100, 100
x = torch.linspace(-10, 10, nx).reshape(-1, 1)  # x范围[-10,10]
t = torch.linspace(0, 8, nt).reshape(-1, 1)   # t范围改为[0,10]

X, T = torch.meshgrid(x.squeeze(), t.squeeze(), indexing='ij')

X_flat = X.reshape(-1, 1)
T_flat = T.reshape(-1, 1)

# 组合输入
X_test = torch.cat([T_flat, X_flat], dim=1)

# 模型预测
with torch.no_grad():
    outputs_pred = model(X_test)
    u_pred = outputs_pred[:, 0:1].reshape(nx, nt).detach().numpy()
    v_pred = outputs_pred[:, 1:2].reshape(nx, nt).detach().numpy()

# 解析解
u_exact = analytical_solution(T_flat, X_flat).reshape(nx, nt).detach().numpy()
v_exact = analytical_solution_v(T_flat, X_flat).reshape(nx, nt).detach().numpy()

# 计算误差
u_error = np.abs(u_pred - u_exact)
v_error = np.abs(v_pred - v_exact)

# 显示热图对比（现在显示u和v）
plt.figure(figsize=(18, 12))

# u的对比
plt.subplot(231)
im = plt.pcolormesh(T.numpy(), X.numpy(), u_exact, cmap='jet', shading='auto')
plt.colorbar(im)
plt.xlabel('t', fontsize=12)
plt.ylabel('x', fontsize=12)
plt.title('Analytical Solution u(x,t)', fontsize=14)

plt.subplot(232)
im = plt.pcolormesh(T.numpy(), X.numpy(), u_pred, cmap='jet', shading='auto')
plt.colorbar(im)
plt.xlabel('t', fontsize=12)
plt.ylabel('x', fontsize=12)
plt.title('Predicted Solution u(x,t)', fontsize=14)

plt.subplot(233)
im = plt.pcolormesh(T.numpy(), X.numpy(), u_error, cmap='jet', shading='auto')
plt.colorbar(im)
plt.xlabel('t', fontsize=12)
plt.ylabel('x', fontsize=12)
plt.title('Absolute Error', fontsize=14)

plt.tight_layout()
plt.show()

# 计算L2误差
total_u_l2_error = np.sqrt(np.mean(np.square(u_pred - u_exact)))
total_v_l2_error = np.sqrt(np.mean(np.square(v_pred - v_exact)))
print(f"u的L2误差: {total_u_l2_error:.6f}")
print(f"v的L2误差: {total_v_l2_error:.6f}")
# Out:
# u的L2误差: 0.077043
# v的L2误差: 0.042948

# %%
# 创建单独的大图显示u的三维对比
fig = plt.figure(figsize=(15, 5))

# 解析解
ax1 = fig.add_subplot(1, 3, 1, projection='3d')
surf1 = ax1.plot_surface(X.numpy(), T.numpy(), u_exact, 
                        cmap='viridis', alpha=0.9, linewidth=0.5, 
                        antialiased=True, linestyle='--')
ax1.set_xlabel('t', fontsize=12)
ax1.set_ylabel('x', fontsize=12)
ax1.set_zlabel('u(x,t)', fontsize=12)
ax1.set_title('Analytical Solution', fontsize=14, fontweight='bold')
ax1.view_init(elev=25, azim=45)
# 移除colorbar

# 设置坐标轴反向
ax1.invert_xaxis()  # t轴反向：从12到0
ax1.invert_yaxis()  # x轴反向：从10到-10

# PINN预测解
ax2 = fig.add_subplot(1, 3, 2, projection='3d')
surf2 = ax2.plot_surface(X.numpy(), T.numpy(), u_pred, 
                        cmap='viridis', alpha=0.9, linewidth=0.5, 
                        antialiased=True, linestyle='--')
ax2.set_xlabel('t', fontsize=12)
ax2.set_ylabel('x', fontsize=12)
ax2.set_zlabel('u(x,t)', fontsize=12)
ax2.set_title('PINN Prediction', fontsize=14, fontweight='bold')
ax2.view_init(elev=25, azim=45)
# 移除colorbar

# 设置坐标轴反向
ax2.invert_xaxis()  # t轴反向：从12到0
ax2.invert_yaxis()  # x轴反向：从10到-10

plt.tight_layout()
plt.show()

# %%
# 绘制不同时间点的解的切片对比
def plot_time_slices():
    """绘制不同时间点的解的切片对比"""
    time_points = [0, 1.6, 3.2, 4.8, 6.4, 8.0]  # 修改时间点为[0, 1.6, 3.2, 4.8, 6.4, 8.0]
    
    fig, axes = plt.subplots(2, 3, figsize=(18, 10))
    axes = axes.flatten()
    
    x_slice = torch.linspace(-10, 10, 200).reshape(-1, 1)
    
    for i, t_val in enumerate(time_points):
        if i >= 6:  # 只有6个子图
            break
            
        t_slice = torch.full_like(x_slice, t_val)
        x_test_slice = torch.cat([t_slice, x_slice], dim=1)
        
        # 模型预测
        with torch.no_grad():
            outputs_slice = model(x_test_slice)
            u_pred_slice = outputs_slice[:, 0:1].detach().numpy()
        
        # 解析解
        u_exact_slice = analytical_solution(t_slice, x_slice).detach().numpy()
        
        # 绘制对比
        axes[i].plot(x_slice.numpy(), u_exact_slice, 'b-', linewidth=2, label='Analytical')
        axes[i].plot(x_slice.numpy(), u_pred_slice, 'r--', linewidth=2, label='PINN')
        axes[i].set_xlabel('x', fontsize=12)
        axes[i].set_ylabel('u(x,t)', fontsize=12)
        axes[i].set_title(f't = {t_val}', fontsize=14)
        axes[i].grid(True, alpha=0.3)
        axes[i].legend()
        
        # 计算该时间点的误差
        error_slice = np.abs(u_pred_slice - u_exact_slice)
        max_error = np.max(error_slice)
        axes[i].text(0.02, 0.98, f'Max Error: {max_error:.4f}', 
                    transform=axes[i].transAxes, fontsize=10,
                    verticalalignment='top',
                    bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))
    
    plt.tight_layout()
    plt.suptitle('Double Soliton Comparison at Different Time Points', fontsize=16, y=1.02)
    plt.show()

# %%
# 修改L2误差计算函数的x_range参数
def compute_and_plot_l2_error(u_analytical, u_predicted, t_points, x_range):
    """计算并绘制不同时间点上的L2误差"""
    # 计算空间步长(用于数值积分)
    dx = (x_range[1] - x_range[0]) / (u_analytical.shape[0] - 1)
    
    # 初始化L2误差数组
    l2_errors_u = np.zeros(len(t_points))
    
    # 对每个时间点计算L2误差
    for i in range(len(t_points)):
        # 计算u的L2误差
        squared_error_u = (u_analytical[:, i] - u_predicted[:, i])**2
        l2_errors_u[i] = np.sqrt(np.sum(squared_error_u) * dx)
    
    # 绘制L2误差随时间的变化
    plt.figure(figsize=(10, 6))
    plt.plot(t_points, l2_errors_u, 'r-', linewidth=2)
    plt.grid(True)
    plt.xlabel('t', fontsize=14)
    plt.ylabel('L2 Error', fontsize=14)
    plt.legend()
    
    # 添加均方根误差信息
    rmse_u = np.sqrt(np.mean(l2_errors_u**2))
    plt.text(0.05, 0.95, f'u RMSE: {rmse_u:.6f}', 
             transform=plt.gca().transAxes, fontsize=12, 
             bbox=dict(facecolor='white', alpha=0.8))
    
    plt.tight_layout()
    plt.show()
    
    return l2_errors_u

# 使用该函数计算并绘制L2误差
t_points = t.squeeze().numpy()  # 时间点数组
x_range = [-10, 10]  # 修改x的范围为[-10, 10]

# 计算并绘制L2误差
l2_errors_u = compute_and_plot_l2_error(
    u_analytical=u_exact, 
    u_predicted=u_pred,
    t_points=t_points,
    x_range=x_range
)
# Out:
# D:\TempFiles\ipykernel_1044\1005194064.py:22: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
