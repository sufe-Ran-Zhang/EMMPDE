# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import time
from collections import OrderedDict

# Klein-Gordon方程参数 (修改为新的参数设定)
a = 0.1  # Klein-Gordon方程系数
b = 1    # 非线性系数
c = 0.3  # 孤立子速度参数
k = np.sqrt(a / (2 * (c**2 - a**2)))  # 波数参数

num_epochs = 1000
nu = 0.1

# %%
def analytical_solution(t, x):
    """
    Klein-Gordon方程精确解
    u(x,t) = sqrt(a/b) * tanh(k(x - c*t))
    """
    u = torch.sqrt(torch.tensor(a/b)) * torch.tanh(k * (x - c * t))
    return u.reshape(-1, 1)

def analytical_solution_v(t, x):
    """
    v = du/dt 的精确解
    v(x,t) = -c * sqrt(a/b) * k * sech^2(k(x - c*t))
    """
    sech_term = 1.0 / torch.cosh(k * (x - c * t))
    v = -c * torch.sqrt(torch.tensor(a/b)) * k * (sech_term ** 2)
    return v.reshape(-1, 1)

def initial_condition_u(x):
    """初始条件 u(x,0) = sqrt(a/b) * tanh(kx)"""
    return torch.sqrt(torch.tensor(a/b)) * torch.tanh(k * x)

def initial_condition_v(x):
    """初始条件 v(x,0) = -c * sqrt(a/b) * k * sech^2(kx)"""
    sech_term = 1.0 / torch.cosh(k * x)
    return -c * torch.sqrt(torch.tensor(a/b)) * k * (sech_term ** 2)

# %%
class PINN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(PINN, self).__init__()
        self.linear1 = nn.Linear(input_size, hidden_size)
        self.linear2 = nn.Linear(hidden_size, hidden_size)
        self.linear3 = nn.Linear(hidden_size, hidden_size)
        self.linear4 = nn.Linear(hidden_size, hidden_size)
        self.output = nn.Linear(hidden_size, 2)  # 输出2个变量：u和v
        self.tanh = nn.Tanh()
        self.iter = 0

    def forward(self, x, t=None):
        if t is not None:
            # 分开的x和t作为输入
            inputs = torch.cat([t, x], dim=1)  # 注意顺序是[t,x]
        else:
            # 已经组合的输入
            inputs = x
            
        out = self.linear1(inputs)
        out = self.tanh(out)
        out = self.linear2(out)
        out = self.tanh(out)
        out = self.linear3(out)
        out = self.tanh(out)
        out = self.linear4(out)
        out = self.tanh(out)
        out = self.output(out)
        return out  # 返回[u, v]

# %%
# 从sampling_PDE.py引入的DNN类
class DNN(torch.nn.Module):
    def __init__(self, layers):
        super(DNN, self).__init__()

        # parameters
        self.depth = len(layers) - 1

        # set up layer order dict
        self.activation = torch.nn.Tanh

        layer_list = list()
        for i in range(self.depth - 1):
            layer_list.append(
                ('layer_%d' % i, torch.nn.Linear(layers[i], layers[i + 1]))
            )
            layer_list.append(('activation_%d' % i, self.activation()))

        layer_list.append(
            ('layer_%d' % (self.depth - 1), torch.nn.Linear(layers[-2], layers[-1]))
        )
        layerDict = OrderedDict(layer_list)

        # deploy layers
        self.layers = torch.nn.Sequential(layerDict)

    def forward(self, x):
        out = self.layers(x)
        return out

# MMPDE采样类
class sampling_MMPDE():
    def __init__(self, X_f, u_fun, layers, lb, ub, nu, AdamIter, LBFGSIter):
        # 边界条件
        self.lb = torch.tensor(lb).float()
        self.ub = torch.tensor(ub).float()

        # 数据
        self.t_f = torch.tensor(X_f[:, 0:1], requires_grad=True).float()
        self.x_f = torch.tensor(X_f[:, 1:2], requires_grad=True).float()
        self.fun = u_fun

        self.layers = layers
        self.nu = nu

        # 深度神经网络
        self.dnn = DNN(layers)

        # 优化器设置
        self.optimizer_Adam = torch.optim.Adam(self.dnn.parameters(),
                                              lr=1e-3,
                                              betas=(0.9, 0.999),
                                              eps=1e-8)
        
        self.AdamIter = AdamIter

        self.optimizer_LBFGS = torch.optim.LBFGS(
            self.dnn.parameters(),
            lr=0.5,
            max_iter=LBFGSIter,
        )

        self.optimizer = None
        self.loss = None
        self.iter = 0
        self.start_time = None

    def detach(self, data):
        return data.detach().cpu().numpy()

    def monitor(self, u, t, x):

        # 计算u对t的一阶导数
        u_t = torch.autograd.grad(
            u, t,
            grad_outputs=torch.ones_like(u),
            retain_graph=True,
            create_graph=True
        )[0]
        
        # 计算u对t的二阶导数(utt)
        u_tt = torch.autograd.grad(
            u_t, t,
            grad_outputs=torch.ones_like(u_t),
            retain_graph=True,
            create_graph=True
        )[0]
        
        # 计算u对x的一阶导数
        u_x = torch.autograd.grad(
            u, x,
            grad_outputs=torch.ones_like(u),
            retain_graph=True,
            create_graph=True
        )[0]
        
        # 计算u对x的二阶导数(uxx)
        u_xx = torch.autograd.grad(
            u_x, x,
            grad_outputs=torch.ones_like(u_x),
            retain_graph=True,
            create_graph=True
        )[0]
        
        # w = (1 + u_xx ** 2 + u_tt ** 2) ** (1 / 2)
        # w = (1 + (0.3 * u_xx ** 2) + (0.4 * u_tt ** 2)) ** (1 / 2)
        w = (1 + u_t ** 2 - a **2 * u_x ** 2 + a * u ** 2 - b/2 * u ** 4) ** (1 / 2)
        
        return w

    def net_sample(self, t, x):
        # 生成新的采样点
        xNew = self.dnn(torch.cat([t, x], dim=1))
        g0 = x - self.lb[1]
        g1 = x - self.ub[1]
        xNew = g0*g1*xNew + x
        return xNew

    def net_f(self, t, x):
        # 计算MMPDE方程的残差
        xNew = self.net_sample(t, x)

        xNew_t = torch.autograd.grad(
            xNew, t,
            grad_outputs=torch.ones_like(xNew),
            retain_graph=True,
            create_graph=True
        )[0]

        xNew_x = torch.autograd.grad(
            xNew, x,
            grad_outputs=torch.ones_like(xNew),
            retain_graph=True,
            create_graph=True
        )[0]
        
        xNew_xx = torch.autograd.grad(
            xNew_x, x,
            grad_outputs=torch.ones_like(xNew_x),
            retain_graph=True,
            create_graph=True
        )[0]

        # 计算解及其导数
        u = self.fun(torch.cat([t, x], dim=1))
        
        # 直接调用修改后的monitor函数，传入u,t,x
        G = self.monitor(u, t, x)

        G_t = torch.autograd.grad(
            G, t,
            grad_outputs=torch.ones_like(G),
            retain_graph=True,
            create_graph=True
        )[0]

        G_x = torch.autograd.grad(
            G, x,
            grad_outputs=torch.ones_like(G),
            retain_graph=True,
            create_graph=True
        )[0]

        # 不再需要G_tx的计算，因为我们已经在monitor函数中处理了二阶导数

        E = G_x * xNew_x + G * xNew_xx
        f = xNew_t*self.nu*(G**2)*(xNew_x**2) + E

        return f

    def loss_func(self):
        # 计算损失函数
        f_pred = self.net_f(self.t_f, self.x_f)
        loss_f = torch.mean(f_pred ** 2)
        
        return loss_f

    def optimize_one_epoch(self):
        if self.start_time is None:
            self.start_time = time.time()

        # 损失函数初始化
        self.optimizer.zero_grad()
        self.loss = self.loss_func()
        self.loss.backward()
        self.iter = self.iter + 1

        if self.iter % 100 == 0:
            loss = self.detach(self.loss)
            print(f"{self.optimizer_name} Iter {self.iter}, Loss: {loss:.6f}")
            elapsed = time.time() - self.start_time
            print(f'Time: {elapsed:.4f}s')
            self.start_time = time.time()

        return self.loss

    def train_Adam(self, optimizer, nIter):
        self.optimizer = optimizer
        self.optimizer_name = 'MMPDE_Adam'
        
        for it in range(nIter):
            self.optimize_one_epoch()
            self.optimizer.step()

    def train_LBFGS(self, optimizer):
        self.optimizer = optimizer
        self.optimizer_name = 'MMPDE_LBFGS'

        def closure():
            loss = self.optimize_one_epoch()
            return loss

        self.optimizer.step(closure)

    def train(self):
        # 训练过程
        print("开始MMPDE训练...")
        self.train_Adam(self.optimizer_Adam, self.AdamIter)
        print("MMPDE_Adam 完成!")
        self.train_LBFGS(self.optimizer_LBFGS)
        print('MMPDE_LBGFS 完成!')

        # 返回新的采样点
        new_x = self.net_sample(self.t_f, self.x_f)
        new_sample = torch.cat([self.t_f, new_x], dim=1)
        return new_sample

# %%
def create_simulation_function(model=None):
    """创建仿真函数，返回u和v的精确解"""
    def simulation_function(xt):
        t, x = xt[:, 0:1], xt[:, 1:2]
        u = analytical_solution(t, x)
        v = analytical_solution_v(t, x)
        return torch.cat([u, v], dim=1)
        
    return simulation_function

# %%
# 修改仿真域范围 (更改为更大的时空域)
lb = [0.0, -10.0]  # [t_min, x_min] - 改为[-10, 10]
ub = [12.0, 10.0]   # [t_max, x_max] - 改为[0, 12]

# 生成均匀分布的采样点
num_samples_per_dim = int(np.sqrt(1000))  # 每个维度上采样约100个点
x_uniform = torch.linspace(-10, 10, num_samples_per_dim)  # x范围改为[-10,10]
t_uniform = torch.linspace(0, 12, num_samples_per_dim)   # t范围改为[0,12]

# 创建均匀网格
X_grid, T_grid = torch.meshgrid(x_uniform, t_uniform, indexing='ij')
x_init = X_grid.reshape(-1, 1)
t_init = T_grid.reshape(-1, 1)

# 合并为输入样本
X_f_init = torch.cat([t_init, x_init], dim=1).numpy()

# 创建模拟函数
sim_func = create_simulation_function()

# 定义MMPDE参数
mmpde_layers = [2, 20, 20, 20, 1]  # 输入(t,x)，输出新的x坐标
adam_iter = 500
lbfgs_iter = 100

# 创建MMPDE采样器并训练
mmpde_sampler = sampling_MMPDE(
    X_f=X_f_init,
    u_fun=sim_func,
    layers=mmpde_layers,
    lb=lb,
    ub=ub,
    nu=nu,
    AdamIter=adam_iter,
    LBFGSIter=lbfgs_iter
)

# 训练MMPDE并获取优化后的采样点
new_samples = mmpde_sampler.train()

# 提取优化后的采样点
t_colloc = new_samples[:, 0:1].clone().detach().requires_grad_(True)
x_colloc = new_samples[:, 1:2].clone().detach().requires_grad_(True)
x_colloc_combined = torch.cat([t_colloc, x_colloc], dim=1)

# 生成边界条件点（修改后的Neumann边界条件在x=-10和x=10处）
N_bc = 1000
t_bc = torch.rand(N_bc, 1) * (ub[0] - lb[0]) + lb[0]  # t ∈ [0, 12]
x_bc_left = torch.full((N_bc//2, 1), -10.0)  # x = -10
x_bc_right = torch.full((N_bc//2, 1), 10.0)  # x = 10
x_bc = torch.cat([x_bc_left, x_bc_right], dim=0)
t_bc_split = torch.split(t_bc, N_bc//2)
x_bc_left_combined = torch.cat([t_bc_split[0], x_bc_left], dim=1)
x_bc_right_combined = torch.cat([t_bc_split[1], x_bc_right], dim=1)
x_bc_combined = torch.cat([x_bc_left_combined, x_bc_right_combined], dim=0)
x_bc_combined.requires_grad_(True)

# 初始条件点(t=0)
N_ic = 1000
x_ic = torch.rand(N_ic, 1) * 20 - 10  # x ∈ [-10, 10]
t_ic = torch.zeros(N_ic, 1)
x_ic_combined = torch.cat([t_ic, x_ic], dim=1)
x_ic_combined.requires_grad_(True)
# Out:
# 开始MMPDE训练...
# MMPDE_Adam Iter 100, Loss: 0.001567
# Time: 0.7643s
# MMPDE_Adam Iter 200, Loss: 0.000686
# Time: 0.7278s
# MMPDE_Adam Iter 300, Loss: 0.000397
# Time: 0.7445s
# MMPDE_Adam Iter 400, Loss: 0.000252
# Time: 0.7398s
# MMPDE_Adam Iter 500, Loss: 0.000170
# Time: 0.7469s
# MMPDE_Adam 完成!
# MMPDE_LBFGS Iter 600, Loss: 0.000003
# Time: 0.7870s
# MMPDE_LBGFS 完成!
# tensor([[ 0.0000,  6.7330],
#         [ 0.0000, -3.8136],
#         [ 0.0000, -1.7233],
#         ...,
#         [ 0.0000, -6.4437],
#         [ 0.0000,  0.7718],
#         [ 0.0000,  1.9949]], requires_grad=True)

# %%
# 可视化采样点
plt.figure(figsize=(10, 6))
plt.scatter(t_colloc.detach().numpy(), x_colloc.detach().numpy(), color='blue', alpha=0.5, label='Collocation', s=10)
plt.xlabel('$t$', fontsize=20)
plt.ylabel('$x$', fontsize=20)
plt.grid(True, alpha=0.5, linestyle='-', linewidth=0.5)
plt.show()

# %%
def x_f_loss_fun(inputs, model):
    """
    计算Klein-Gordon方程PDE残差（一阶系统形式）:
    du/dt = v
    dv/dt = a^2 * u_xx - a * u + b * u^3
    """
    if not inputs.requires_grad:
        inputs = Variable(inputs, requires_grad=True)
    
    # 获取模型预测的u和v
    outputs = model(inputs)
    u = outputs[:, 0:1]  # 第一个输出是u
    v = outputs[:, 1:2]  # 第二个输出是v
    
    # 提取坐标
    t = inputs[:, 0:1]
    x = inputs[:, 1:2]
    
    # 计算u关于输入的梯度
    u_grad = torch.autograd.grad(u, inputs, grad_outputs=torch.ones_like(u), create_graph=True)[0]
    u_t = u_grad[:, 0:1]  # du/dt
    u_x = u_grad[:, 1:2]  # du/dx
    
    # 计算v关于输入的梯度
    v_grad = torch.autograd.grad(v, inputs, grad_outputs=torch.ones_like(v), create_graph=True)[0]
    v_t = v_grad[:, 0:1]  # dv/dt
    
    # 计算u_xx - 对u_x再求一次关于x的导数
    u_xx = torch.autograd.grad(u_x, inputs, grad_outputs=torch.ones_like(u_x), create_graph=True)[0][:, 1:2]
    
    # 计算PDE残差
    # 第一个方程：du/dt = v
    f1 = u_t - v
    
    # 第二个方程：dv/dt = a^2 * u_xx - a * u + b * u^3
    f2 = v_t - (a**2 * u_xx - a * u + b * (u**3))
    
    return torch.cat([f1, f2], dim=1)

# %%
def boundary_loss(model, x_bc):
    """
    边界条件损失：修改后的Neumann边界条件
    u_x(-10, t) = k * sqrt(a/b) * sech^2(k(-10 - c*t))
    u_x(10, t) = k * sqrt(a/b) * sech^2(k(10 - c*t))
    """
    inputs = x_bc.clone().requires_grad_(True)
    outputs = model(inputs)
    u = outputs[:, 0:1]  # 获取u
    
    # 计算u_x
    u_x = torch.autograd.grad(
        u, inputs,
        grad_outputs=torch.ones_like(u),
        create_graph=True
    )[0][:, 1:2]  # 对x的导数
    
    # 提取时间和空间坐标
    t = inputs[:, 0:1]
    x = inputs[:, 1:2]
    
    # 计算理论边界条件值
    # 对于x=-10的点
    mask_left = (x == -10.0).float()
    sech_left = 1.0 / torch.cosh(k * (-10.0 - c * t))
    u_x_left_target = k * torch.sqrt(torch.tensor(a/b)) * (sech_left ** 2)
    
    # 对于x=10的点  
    mask_right = (x == 10.0).float()
    sech_right = 1.0 / torch.cosh(k * (10.0 - c * t))
    u_x_right_target = k * torch.sqrt(torch.tensor(a/b)) * (sech_right ** 2)
    
    # 组合目标值
    u_x_target = mask_left * u_x_left_target + mask_right * u_x_right_target
    
    # 计算边界条件损失
    return torch.mean((u_x - u_x_target)**2)

def initial_condition_loss(model, x_ic):
    """
    初始条件损失：
    1. u(x,0) = sqrt(a/b) * tanh(kx)
    2. v(x,0) = -c * sqrt(a/b) * k * sech^2(kx)
    """
    outputs = model(x_ic)
    u_pred = outputs[:, 0:1]
    v_pred = outputs[:, 1:2]
    
    # 提取x坐标
    x = x_ic[:, 1:2]
    
    # 计算初始条件目标值
    u_ic_target = initial_condition_u(x)
    v_ic_target = initial_condition_v(x)
    
    # 计算损失
    u_loss = torch.mean((u_pred - u_ic_target)**2)
    v_loss = torch.mean((v_pred - v_ic_target)**2)
    
    return u_loss + v_loss

# %%
# 创建模型
model = PINN(2, 40)  # 输入维度是2 (t和x)，隐藏层维度40
model.iter = 0  # 添加迭代计数器

# 优化器参数
adam_iter = 5000  # Adam迭代次数
lbfgs_iter = 10000  # LBFGS迭代次数
adam_lr = 0.001  # Adam学习率
lbfgs_lr = 0.5  # LBFGS学习率

# 定义Adam优化器
optimizer_adam = torch.optim.Adam(model.parameters(), lr=adam_lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer_adam, step_size=1000, gamma=0.5)

# 第一阶段：Adam优化
print("开始第一阶段: Adam优化...")
for epoch in range(adam_iter):
    optimizer_adam.zero_grad()
    
    # 计算PDE残差
    f = x_f_loss_fun(x_colloc_combined, model)
    loss_pde = torch.mean(f**2)
    
    # 计算边界条件损失
    loss_bc = boundary_loss(model, x_bc_combined)
    
    # 计算初始条件损失
    loss_ic = initial_condition_loss(model, x_ic_combined)
    
    # 总损失
    total_loss = loss_pde + 10.0 * loss_bc + 10.0 * loss_ic
    
    total_loss.backward()
    
    # 添加梯度裁剪
    torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
    
    optimizer_adam.step()
    scheduler.step()
    model.iter += 1
    
    if epoch % 100 == 0:
        print(f"Epoch: {epoch}/{adam_iter}, "
              f"Loss: {total_loss.item():.6e}, "
              f"PDE: {loss_pde.item():.6e}, "
              f"BC: {loss_bc.item():.6e}, "
              f"IC: {loss_ic.item():.6e}")

# 定义LBFGS优化器
optimizer_lbfgs = torch.optim.LBFGS(
    model.parameters(), 
    lr=lbfgs_lr, 
    max_iter=20,
    max_eval=25,
    tolerance_grad=1e-9,
    tolerance_change=1e-12,
    history_size=50,
    line_search_fn="strong_wolfe"
)

# 第二阶段：LBFGS优化
print("开始第二阶段: LBFGS优化...")

# 在训练循环中修改损失计算
def closure():
    optimizer_lbfgs.zero_grad()
    
    # 计算PDE残差
    f = x_f_loss_fun(x_colloc_combined, model)
    loss_pde = torch.mean(f**2)  # f现在是2列的矩阵
    
    # 计算边界条件损失
    loss_bc = boundary_loss(model, x_bc_combined)
    
    # 计算初始条件损失
    loss_ic = initial_condition_loss(model, x_ic_combined)
    
    # 总损失
    total_loss = loss_pde + 10.0 * loss_bc + 10.0 * loss_ic
    
    total_loss.backward()
    
    model.iter += 1
    if model.iter % 100 == 0:
        print(f"LBFGS Iter: {model.iter}, "
              f"Loss: {total_loss.item():.6e}, "
              f"PDE: {loss_pde.item():.6e}, "
              f"BC: {loss_bc.item():.6e}, "
              f"IC: {loss_ic.item():.6e}")
    
    return total_loss

# 运行LBFGS优化
for i in range(lbfgs_iter // 20):  # 由于max_iter设为20，我们在外层循环控制总迭代次数
    optimizer_lbfgs.step(closure)
    current_loss = closure()
    print(f"LBFGS外循环 {i+1}/{lbfgs_iter//20}, 当前损失: {current_loss.item():.6e}")

print("优化完成!")
# Out:
# 开始第一阶段: Adam优化...
# Epoch: 0/5000, Loss: 1.129340e+00, PDE: 1.394923e-02, BC: 7.081164e-05, IC: 1.114682e-01
# Epoch: 100/5000, Loss: 7.118169e-04, PDE: 2.063907e-04, BC: 1.397056e-05, IC: 3.657206e-05
# Epoch: 200/5000, Loss: 2.428310e-04, PDE: 1.163759e-04, BC: 1.600643e-06, IC: 1.104487e-05
# Epoch: 300/5000, Loss: 1.270274e-04, PDE: 7.999831e-05, BC: 5.967592e-07, IC: 4.106148e-06
# Epoch: 400/5000, Loss: 8.587922e-05, PDE: 6.038957e-05, BC: 3.901662e-07, IC: 2.158799e-06
# Epoch: 500/5000, Loss: 6.558319e-05, PDE: 4.793359e-05, BC: 2.929130e-07, IC: 1.472047e-06
# Epoch: 600/5000, Loss: 5.278014e-05, PDE: 3.940152e-05, BC: 2.198710e-07, IC: 1.117991e-06
# Epoch: 700/5000, Loss: 4.365799e-05, PDE: 3.325346e-05, BC: 1.640342e-07, IC: 8.764185e-07
# Epoch: 800/5000, Loss: 3.682136e-05, PDE: 2.868098e-05, BC: 1.228899e-07, IC: 6.911479e-07
# Epoch: 900/5000, Loss: 3.153685e-05, PDE: 2.512461e-05, BC: 9.307949e-08, IC: 5.481446e-07
# Epoch: 1000/5000, Loss: 2.749759e-05, PDE: 2.255979e-05, BC: 7.321566e-08, IC: 4.205640e-07
# Epoch: 1100/5000, Loss: 2.558321e-05, PDE: 2.124174e-05, BC: 6.614413e-08, IC: 3.680026e-07
# Epoch: 1200/5000, Loss: 2.389833e-05, PDE: 2.003371e-05, BC: 5.947131e-08, IC: 3.269903e-07
# Epoch: 1300/5000, Loss: 2.232476e-05, PDE: 1.889879e-05, BC: 5.337170e-08, IC: 2.892247e-07
# Epoch: 1400/5000, Loss: 2.085615e-05, PDE: 1.782876e-05, BC: 4.797191e-08, IC: 2.547669e-07
# Epoch: 1500/5000, Loss: 1.948877e-05, PDE: 1.681906e-05, BC: 4.334266e-08, IC: 2.236291e-07
# Epoch: 1600/5000, Loss: 1.821941e-05, PDE: 1.586664e-05, BC: 3.948562e-08, IC: 1.957923e-07
# Epoch: 1700/5000, Loss: 1.704429e-05, PDE: 1.496886e-05, BC: 3.634993e-08, IC: 1.711924e-07
# Epoch: 1800/5000, Loss: 1.595880e-05, PDE: 1.412324e-05, BC: 3.382984e-08, IC: 1.497267e-07
# Epoch: 1900/5000, Loss: 1.495747e-05, PDE: 1.332711e-05, BC: 3.180089e-08, IC: 1.312344e-07
# Epoch: 2000/5000, Loss: 1.403428e-05, PDE: 1.257771e-05, BC: 3.015163e-08, IC: 1.155046e-07
# Epoch: 2100/5000, Loss: 1.359517e-05, PDE: 1.221545e-05, BC: 2.943589e-08, IC: 1.085363e-07
# Epoch: 2200/5000, Loss: 1.316216e-05, PDE: 1.185442e-05, BC: 2.877285e-08, IC: 1.020007e-07
# Epoch: 2300/5000, Loss: 1.273593e-05, PDE: 1.149526e-05, BC: 2.816006e-08, IC: 9.590757e-08
# Epoch: 2400/5000, Loss: 1.231716e-05, PDE: 1.113851e-05, BC: 2.760290e-08, IC: 9.026260e-08
# Epoch: 2500/5000, Loss: 1.190636e-05, PDE: 1.078471e-05, BC: 2.710138e-08, IC: 8.506442e-08
# Epoch: 2600/5000, Loss: 1.150376e-05, PDE: 1.043425e-05, BC: 2.665227e-08, IC: 8.029940e-08
# Epoch: 2700/5000, Loss: 1.110949e-05, PDE: 1.008739e-05, BC: 2.625627e-08, IC: 7.595391e-08
# Epoch: 2800/5000, Loss: 1.072340e-05, PDE: 9.744298e-06, BC: 2.590659e-08, IC: 7.200372e-08
# Epoch: 2900/5000, Loss: 1.034521e-05, PDE: 9.405012e-06, BC: 2.559778e-08, IC: 6.842156e-08
# Epoch: 3000/5000, Loss: 9.974449e-06, PDE: 9.069508e-06, BC: 2.531553e-08, IC: 6.517860e-08
# Epoch: 3100/5000, Loss: 9.789574e-06, PDE: 8.901185e-06, BC: 2.518014e-08, IC: 6.365867e-08
# Epoch: 3200/5000, Loss: 9.601691e-06, PDE: 8.729543e-06, BC: 2.503953e-08, IC: 6.217522e-08
# Epoch: 3300/5000, Loss: 9.410894e-06, PDE: 8.554629e-06, BC: 2.489588e-08, IC: 6.073063e-08
# Epoch: 3400/5000, Loss: 9.217259e-06, PDE: 8.376592e-06, BC: 2.474513e-08, IC: 5.932154e-08
# Epoch: 3500/5000, Loss: 9.020865e-06, PDE: 8.195517e-06, BC: 2.458594e-08, IC: 5.794891e-08
# Epoch: 3600/5000, Loss: 8.821838e-06, PDE: 8.011551e-06, BC: 2.441606e-08, IC: 5.661266e-08
# Epoch: 3700/5000, Loss: 8.620277e-06, PDE: 7.824871e-06, BC: 2.423122e-08, IC: 5.530937e-08
# Epoch: 3800/5000, Loss: 8.416291e-06, PDE: 7.635664e-06, BC: 2.402640e-08, IC: 5.403638e-08
# Epoch: 3900/5000, Loss: 8.210023e-06, PDE: 7.444122e-06, BC: 2.380109e-08, IC: 5.278894e-08
# Epoch: 4000/5000, Loss: 8.001677e-06, PDE: 7.250472e-06, BC: 2.355447e-08, IC: 5.156610e-08
# Epoch: 4100/5000, Loss: 7.895555e-06, PDE: 7.151806e-06, BC: 2.341970e-08, IC: 5.095510e-08
# Epoch: 4200/5000, Loss: 7.786301e-06, PDE: 7.050208e-06, BC: 2.327660e-08, IC: 5.033261e-08
# Epoch: 4300/5000, Loss: 7.673965e-06, PDE: 6.945770e-06, BC: 2.312186e-08, IC: 4.969769e-08
# Epoch: 4400/5000, Loss: 7.558578e-06, PDE: 6.838499e-06, BC: 2.295673e-08, IC: 4.905116e-08
# Epoch: 4500/5000, Loss: 7.440166e-06, PDE: 6.728465e-06, BC: 2.277842e-08, IC: 4.839157e-08
# Epoch: 4600/5000, Loss: 7.318809e-06, PDE: 6.615731e-06, BC: 2.258639e-08, IC: 4.772142e-08
# Epoch: 4700/5000, Loss: 7.194557e-06, PDE: 6.500389e-06, BC: 2.238201e-08, IC: 4.703478e-08
# Epoch: 4800/5000, Loss: 7.067513e-06, PDE: 6.382508e-06, BC: 2.216533e-08, IC: 4.633518e-08
# Epoch: 4900/5000, Loss: 6.937806e-06, PDE: 6.262244e-06, BC: 2.193950e-08, IC: 4.561672e-08
# 开始第二阶段: LBFGS优化...
# LBFGS外循环 1/500, 当前损失: 6.501336e-06
# LBFGS外循环 2/500, 当前损失: 5.872971e-06
# LBFGS外循环 3/500, 当前损失: 5.305420e-06
# LBFGS外循环 4/500, 当前损失: 4.739839e-06
# LBFGS Iter: 5100, Loss: 4.506220e-06, PDE: 3.710642e-06, BC: 3.712008e-08, IC: 4.243773e-08
# LBFGS外循环 5/500, 当前损失: 4.239731e-06
# LBFGS外循环 6/500, 当前损失: 3.960630e-06
# LBFGS外循环 7/500, 当前损失: 3.561869e-06
# LBFGS外循环 8/500, 当前损失: 3.269565e-06
# LBFGS Iter: 5200, Loss: 3.176912e-06, PDE: 2.742469e-06, BC: 1.252145e-08, IC: 3.092282e-08
# LBFGS外循环 9/500, 当前损失: 3.148958e-06
# LBFGS外循环 10/500, 当前损失: 2.918735e-06
# LBFGS外循环 11/500, 当前损失: 2.591075e-06
# LBFGS外循环 12/500, 当前损失: 2.380842e-06
# LBFGS外循环 13/500, 当前损失: 2.184687e-06
# LBFGS Iter: 5300, Loss: 2.141353e-06, PDE: 1.871310e-06, BC: 8.418763e-09, IC: 1.858554e-08
# LBFGS外循环 14/500, 当前损失: 1.867336e-06
# LBFGS外循环 15/500, 当前损失: 1.601421e-06
# LBFGS外循环 16/500, 当前损失: 1.425829e-06
# LBFGS外循环 17/500, 当前损失: 1.254735e-06
# LBFGS Iter: 5400, Loss: 1.214318e-06, PDE: 1.010404e-06, BC: 8.616959e-09, IC: 1.177439e-08
# LBFGS外循环 18/500, 当前损失: 1.214318e-06
# LBFGS外循环 19/500, 当前损失: 1.047878e-06
# LBFGS外循环 20/500, 当前损失: 9.529801e-07
# LBFGS外循环 21/500, 当前损失: 8.212101e-07
# LBFGS外循环 22/500, 当前损失: 7.352131e-07
# LBFGS Iter: 5500, Loss: 6.906098e-07, PDE: 5.544721e-07, BC: 4.209294e-09, IC: 9.404470e-09
# LBFGS外循环 23/500, 当前损失: 6.361296e-07
# LBFGS外循环 24/500, 当前损失: 6.067039e-07
# LBFGS外循环 25/500, 当前损失: 5.641856e-07
# LBFGS外循环 26/500, 当前损失: 5.279489e-07
# LBFGS Iter: 5600, Loss: 4.973174e-07, PDE: 4.085107e-07, BC: 3.524687e-09, IC: 5.355985e-09
# LBFGS外循环 27/500, 当前损失: 4.973174e-07
# LBFGS外循环 28/500, 当前损失: 4.703215e-07
# LBFGS外循环 29/500, 当前损失: 4.459465e-07
# LBFGS外循环 30/500, 当前损失: 4.299749e-07
# LBFGS外循环 31/500, 当前损失: 4.065693e-07
# LBFGS Iter: 5700, Loss: 4.037105e-07, PDE: 3.310469e-07, BC: 2.624887e-09, IC: 4.641479e-09
# LBFGS外循环 32/500, 当前损失: 3.930909e-07
# LBFGS外循环 33/500, 当前损失: 3.735613e-07
# LBFGS外循环 34/500, 当前损失: 3.531906e-07
# LBFGS外循环 35/500, 当前损失: 3.484372e-07
# LBFGS Iter: 5800, Loss: 3.434231e-07, PDE: 2.769311e-07, BC: 2.074928e-09, IC: 4.574274e-09
# LBFGS外循环 36/500, 当前损失: 3.385711e-07
# LBFGS外循环 37/500, 当前损失: 3.325302e-07
# LBFGS外循环 38/500, 当前损失: 3.131672e-07
# LBFGS外循环 39/500, 当前损失: 2.846327e-07
# LBFGS Iter: 5900, Loss: 2.739287e-07, PDE: 2.151088e-07, BC: 2.287517e-09, IC: 3.594479e-09
# LBFGS外循环 40/500, 当前损失: 2.731016e-07
# LBFGS外循环 41/500, 当前损失: 2.690511e-07
# LBFGS外循环 42/500, 当前损失: 2.536464e-07
# LBFGS外循环 43/500, 当前损失: 2.463052e-07
# LBFGS外循环 44/500, 当前损失: 2.316097e-07
# LBFGS Iter: 6000, Loss: 2.316097e-07, PDE: 1.770768e-07, BC: 2.363115e-09, IC: 3.090184e-09
# LBFGS外循环 45/500, 当前损失: 2.186610e-07
# LBFGS外循环 46/500, 当前损失: 2.116028e-07
# LBFGS外循环 47/500, 当前损失: 2.102581e-07
# LBFGS外循环 48/500, 当前损失: 2.097593e-07
# LBFGS Iter: 6100, Loss: 2.097494e-07, PDE: 1.619660e-07, BC: 2.087157e-09, IC: 2.691180e-09
# LBFGS外循环 49/500, 当前损失: 2.084901e-07
# LBFGS外循环 50/500, 当前损失: 2.080616e-07
# LBFGS外循环 51/500, 当前损失: 2.078124e-07
# LBFGS Iter: 6200, Loss: 2.076767e-07, PDE: 1.609489e-07, BC: 2.049120e-09, IC: 2.623657e-09
# LBFGS外循环 52/500, 当前损失: 2.076333e-07
# LBFGS外循环 53/500, 当前损失: 2.074131e-07
# LBFGS外循环 54/500, 当前损失: 2.072041e-07
# LBFGS外循环 55/500, 当前损失: 2.065065e-07
# LBFGS Iter: 6300, Loss: 2.064151e-07, PDE: 1.602692e-07, BC: 2.021045e-09, IC: 2.593540e-09
# LBFGS外循环 56/500, 当前损失: 2.063377e-07
# LBFGS外循环 57/500, 当前损失: 2.024644e-07
# LBFGS外循环 58/500, 当前损失: 2.007211e-07
# LBFGS外循环 59/500, 当前损失: 1.965720e-07
# LBFGS Iter: 6400, Loss: 1.964989e-07, PDE: 1.554173e-07, BC: 1.777881e-09, IC: 2.330283e-09
# LBFGS外循环 60/500, 当前损失: 1.959200e-07
# LBFGS外循环 61/500, 当前损失: 1.954082e-07
# LBFGS外循环 62/500, 当前损失: 1.951514e-07
# LBFGS Iter: 6500, Loss: 1.949365e-07, PDE: 1.541817e-07, BC: 1.809278e-09, IC: 2.266204e-09
# LBFGS外循环 63/500, 当前损失: 1.949122e-07
# LBFGS外循环 64/500, 当前损失: 1.944006e-07
# LBFGS外循环 65/500, 当前损失: 1.911901e-07
# LBFGS外循环 66/500, 当前损失: 1.871569e-07
# LBFGS Iter: 6600, Loss: 1.869273e-07, PDE: 1.463993e-07, BC: 1.915657e-09, IC: 2.137141e-09
# LBFGS外循环 67/500, 当前损失: 1.867603e-07
# LBFGS外循环 68/500, 当前损失: 1.864620e-07
# LBFGS外循环 69/500, 当前损失: 1.858965e-07
# LBFGS外循环 70/500, 当前损失: 1.855721e-07
# LBFGS Iter: 6700, Loss: 1.855405e-07, PDE: 1.456551e-07, BC: 1.888026e-09, IC: 2.100518e-09
# LBFGS外循环 71/500, 当前损失: 1.850951e-07
# LBFGS外循环 72/500, 当前损失: 1.849807e-07
# LBFGS外循环 73/500, 当前损失: 1.847867e-07
# LBFGS外循环 74/500, 当前损失: 1.843926e-07
# LBFGS Iter: 6800, Loss: 1.843798e-07, PDE: 1.449279e-07, BC: 1.871614e-09, IC: 2.073577e-09
# LBFGS外循环 75/500, 当前损失: 1.843621e-07
# LBFGS外循环 76/500, 当前损失: 1.837262e-07
# LBFGS外循环 77/500, 当前损失: 1.835358e-07
# LBFGS外循环 78/500, 当前损失: 1.834172e-07
# LBFGS Iter: 6900, Loss: 1.833299e-07, PDE: 1.441815e-07, BC: 1.862974e-09, IC: 2.051874e-09
# LBFGS外循环 79/500, 当前损失: 1.833216e-07
# LBFGS外循环 80/500, 当前损失: 1.833213e-07
# LBFGS外循环 81/500, 当前损失: 1.833212e-07
# LBFGS外循环 82/500, 当前损失: 1.833212e-07
# LBFGS外循环 83/500, 当前损失: 1.833212e-07
# LBFGS外循环 84/500, 当前损失: 1.833212e-07
# LBFGS外循环 85/500, 当前损失: 1.833212e-07
# LBFGS外循环 86/500, 当前损失: 1.833212e-07
# LBFGS外循环 87/500, 当前损失: 1.833212e-07
# LBFGS外循环 88/500, 当前损失: 1.833212e-07
# LBFGS外循环 89/500, 当前损失: 1.833212e-07
# LBFGS外循环 90/500, 当前损失: 1.833212e-07
# LBFGS外循环 91/500, 当前损失: 1.833212e-07
# LBFGS外循环 92/500, 当前损失: 1.833212e-07
# LBFGS外循环 93/500, 当前损失: 1.833212e-07
# LBFGS Iter: 7000, Loss: 1.833213e-07, PDE: 1.441665e-07, BC: 1.863477e-09, IC: 2.051999e-09
# LBFGS外循环 94/500, 当前损失: 1.833212e-07
# LBFGS外循环 95/500, 当前损失: 1.833212e-07
# LBFGS外循环 96/500, 当前损失: 1.833212e-07
# LBFGS外循环 97/500, 当前损失: 1.833212e-07
# LBFGS外循环 98/500, 当前损失: 1.833212e-07
# LBFGS外循环 99/500, 当前损失: 1.833212e-07
# LBFGS外循环 100/500, 当前损失: 1.833212e-07
# LBFGS外循环 101/500, 当前损失: 1.833212e-07
# LBFGS外循环 102/500, 当前损失: 1.833212e-07
# LBFGS外循环 103/500, 当前损失: 1.833212e-07
# LBFGS外循环 104/500, 当前损失: 1.833212e-07
# LBFGS外循环 105/500, 当前损失: 1.833212e-07
# LBFGS外循环 106/500, 当前损失: 1.833212e-07
# LBFGS外循环 107/500, 当前损失: 1.833212e-07
# LBFGS外循环 108/500, 当前损失: 1.833212e-07
# LBFGS外循环 109/500, 当前损失: 1.833212e-07
# LBFGS外循环 110/500, 当前损失: 1.833212e-07
# LBFGS Iter: 7100, Loss: 1.833228e-07, PDE: 1.441668e-07, BC: 1.863434e-09, IC: 2.052166e-09
# LBFGS外循环 111/500, 当前损失: 1.833212e-07
# LBFGS外循环 112/500, 当前损失: 1.833212e-07
# LBFGS外循环 113/500, 当前损失: 1.833212e-07
# LBFGS外循环 114/500, 当前损失: 1.833212e-07
# LBFGS外循环 115/500, 当前损失: 1.833212e-07
# LBFGS外循环 116/500, 当前损失: 1.833212e-07
# LBFGS外循环 117/500, 当前损失: 1.833212e-07
# LBFGS外循环 118/500, 当前损失: 1.833212e-07
# LBFGS外循环 119/500, 当前损失: 1.833212e-07
# LBFGS外循环 120/500, 当前损失: 1.833212e-07
# LBFGS外循环 121/500, 当前损失: 1.833212e-07
# LBFGS外循环 122/500, 当前损失: 1.833212e-07
# LBFGS外循环 123/500, 当前损失: 1.833212e-07
# LBFGS外循环 124/500, 当前损失: 1.833212e-07
# LBFGS外循环 125/500, 当前损失: 1.833212e-07
# LBFGS外循环 126/500, 当前损失: 1.833212e-07
# LBFGS外循环 127/500, 当前损失: 1.833212e-07
# LBFGS Iter: 7200, Loss: 1.833212e-07, PDE: 1.441665e-07, BC: 1.863477e-09, IC: 2.051994e-09
# LBFGS外循环 128/500, 当前损失: 1.833212e-07
# LBFGS外循环 129/500, 当前损失: 1.833212e-07
# LBFGS外循环 130/500, 当前损失: 1.833212e-07
# LBFGS外循环 131/500, 当前损失: 1.833212e-07
# LBFGS外循环 132/500, 当前损失: 1.833212e-07
# LBFGS外循环 133/500, 当前损失: 1.833212e-07
# LBFGS外循环 134/500, 当前损失: 1.833212e-07
# LBFGS外循环 135/500, 当前损失: 1.833212e-07
# LBFGS外循环 136/500, 当前损失: 1.833212e-07
# LBFGS外循环 137/500, 当前损失: 1.833212e-07
# LBFGS外循环 138/500, 当前损失: 1.833212e-07
# LBFGS外循环 139/500, 当前损失: 1.833212e-07
# LBFGS外循环 140/500, 当前损失: 1.833212e-07
# LBFGS外循环 141/500, 当前损失: 1.833212e-07
# LBFGS外循环 142/500, 当前损失: 1.833212e-07
# LBFGS外循环 143/500, 当前损失: 1.833212e-07
# LBFGS Iter: 7300, Loss: 1.833213e-07, PDE: 1.441665e-07, BC: 1.863477e-09, IC: 2.051999e-09
# LBFGS外循环 144/500, 当前损失: 1.833212e-07
# LBFGS外循环 145/500, 当前损失: 1.833212e-07
# LBFGS外循环 146/500, 当前损失: 1.833212e-07
# LBFGS外循环 147/500, 当前损失: 1.833212e-07
# LBFGS外循环 148/500, 当前损失: 1.833212e-07
# LBFGS外循环 149/500, 当前损失: 1.833212e-07
# LBFGS外循环 150/500, 当前损失: 1.833212e-07
# LBFGS外循环 151/500, 当前损失: 1.833212e-07
# LBFGS外循环 152/500, 当前损失: 1.833212e-07
# LBFGS外循环 153/500, 当前损失: 1.833212e-07
# LBFGS外循环 154/500, 当前损失: 1.833212e-07
# LBFGS外循环 155/500, 当前损失: 1.833212e-07
# LBFGS外循环 156/500, 当前损失: 1.833212e-07
# LBFGS外循环 157/500, 当前损失: 1.833212e-07
# LBFGS外循环 158/500, 当前损失: 1.833212e-07
# LBFGS外循环 159/500, 当前损失: 1.833212e-07
# LBFGS外循环 160/500, 当前损失: 1.833212e-07
# LBFGS Iter: 7400, Loss: 1.833228e-07, PDE: 1.441668e-07, BC: 1.863434e-09, IC: 2.052166e-09
# LBFGS外循环 161/500, 当前损失: 1.833212e-07
# LBFGS外循环 162/500, 当前损失: 1.833212e-07
# LBFGS外循环 163/500, 当前损失: 1.833212e-07
# LBFGS外循环 164/500, 当前损失: 1.833212e-07
# LBFGS外循环 165/500, 当前损失: 1.833212e-07
# LBFGS外循环 166/500, 当前损失: 1.833212e-07
# LBFGS外循环 167/500, 当前损失: 1.833212e-07
# LBFGS外循环 168/500, 当前损失: 1.833212e-07
# LBFGS外循环 169/500, 当前损失: 1.833212e-07
# LBFGS外循环 170/500, 当前损失: 1.833212e-07
# LBFGS外循环 171/500, 当前损失: 1.833212e-07
# LBFGS外循环 172/500, 当前损失: 1.833212e-07
# LBFGS外循环 173/500, 当前损失: 1.833212e-07
# LBFGS外循环 174/500, 当前损失: 1.833212e-07
# LBFGS外循环 175/500, 当前损失: 1.833212e-07
# LBFGS外循环 176/500, 当前损失: 1.833212e-07
# LBFGS外循环 177/500, 当前损失: 1.833212e-07
# LBFGS Iter: 7500, Loss: 1.833212e-07, PDE: 1.441665e-07, BC: 1.863477e-09, IC: 2.051994e-09
# LBFGS外循环 178/500, 当前损失: 1.833212e-07
# LBFGS外循环 179/500, 当前损失: 1.833212e-07
# LBFGS外循环 180/500, 当前损失: 1.833212e-07
# LBFGS外循环 181/500, 当前损失: 1.833212e-07
# LBFGS外循环 182/500, 当前损失: 1.833212e-07
# LBFGS外循环 183/500, 当前损失: 1.833212e-07
# LBFGS外循环 184/500, 当前损失: 1.833212e-07
# LBFGS外循环 185/500, 当前损失: 1.833212e-07
# LBFGS外循环 186/500, 当前损失: 1.833212e-07
# LBFGS外循环 187/500, 当前损失: 1.833212e-07
# LBFGS外循环 188/500, 当前损失: 1.833212e-07
# LBFGS外循环 189/500, 当前损失: 1.833212e-07
# LBFGS外循环 190/500, 当前损失: 1.833212e-07
# LBFGS外循环 191/500, 当前损失: 1.833212e-07
# LBFGS外循环 192/500, 当前损失: 1.833212e-07
# LBFGS外循环 193/500, 当前损失: 1.833212e-07
# LBFGS Iter: 7600, Loss: 1.833213e-07, PDE: 1.441665e-07, BC: 1.863477e-09, IC: 2.051999e-09
# LBFGS外循环 194/500, 当前损失: 1.833212e-07
# LBFGS外循环 195/500, 当前损失: 1.833212e-07
# LBFGS外循环 196/500, 当前损失: 1.833212e-07
# LBFGS外循环 197/500, 当前损失: 1.833212e-07
# LBFGS外循环 198/500, 当前损失: 1.833212e-07
# LBFGS外循环 199/500, 当前损失: 1.833212e-07
# LBFGS外循环 200/500, 当前损失: 1.833212e-07
# LBFGS外循环 201/500, 当前损失: 1.833212e-07
# LBFGS外循环 202/500, 当前损失: 1.833212e-07
# LBFGS外循环 203/500, 当前损失: 1.833212e-07
# LBFGS外循环 204/500, 当前损失: 1.833212e-07
# LBFGS外循环 205/500, 当前损失: 1.833212e-07
# LBFGS外循环 206/500, 当前损失: 1.833212e-07
# LBFGS外循环 207/500, 当前损失: 1.833212e-07
# LBFGS外循环 208/500, 当前损失: 1.833212e-07
# LBFGS外循环 209/500, 当前损失: 1.833212e-07
# LBFGS外循环 210/500, 当前损失: 1.833212e-07
# LBFGS Iter: 7700, Loss: 1.833228e-07, PDE: 1.441668e-07, BC: 1.863434e-09, IC: 2.052166e-09
# LBFGS外循环 211/500, 当前损失: 1.833212e-07
# LBFGS外循环 212/500, 当前损失: 1.833212e-07
# LBFGS外循环 213/500, 当前损失: 1.833212e-07
# LBFGS外循环 214/500, 当前损失: 1.833212e-07
# LBFGS外循环 215/500, 当前损失: 1.833212e-07
# LBFGS外循环 216/500, 当前损失: 1.833212e-07
# LBFGS外循环 217/500, 当前损失: 1.833212e-07
# LBFGS外循环 218/500, 当前损失: 1.833212e-07
# LBFGS外循环 219/500, 当前损失: 1.833212e-07
# LBFGS外循环 220/500, 当前损失: 1.833212e-07
# LBFGS外循环 221/500, 当前损失: 1.833212e-07
# LBFGS外循环 222/500, 当前损失: 1.833212e-07
# LBFGS外循环 223/500, 当前损失: 1.833212e-07
# LBFGS外循环 224/500, 当前损失: 1.833212e-07
# LBFGS外循环 225/500, 当前损失: 1.833212e-07
# LBFGS外循环 226/500, 当前损失: 1.833212e-07
# LBFGS外循环 227/500, 当前损失: 1.833212e-07
# LBFGS Iter: 7800, Loss: 1.833212e-07, PDE: 1.441665e-07, BC: 1.863477e-09, IC: 2.051994e-09
# LBFGS外循环 228/500, 当前损失: 1.833212e-07
# LBFGS外循环 229/500, 当前损失: 1.833212e-07
# LBFGS外循环 230/500, 当前损失: 1.833212e-07
# LBFGS外循环 231/500, 当前损失: 1.833212e-07
# LBFGS外循环 232/500, 当前损失: 1.833212e-07
# LBFGS外循环 233/500, 当前损失: 1.833212e-07
# LBFGS外循环 234/500, 当前损失: 1.833212e-07
# LBFGS外循环 235/500, 当前损失: 1.833212e-07
# LBFGS外循环 236/500, 当前损失: 1.833212e-07
# LBFGS外循环 237/500, 当前损失: 1.833212e-07
# LBFGS外循环 238/500, 当前损失: 1.833212e-07
# LBFGS外循环 239/500, 当前损失: 1.833212e-07
# LBFGS外循环 240/500, 当前损失: 1.833212e-07
# LBFGS外循环 241/500, 当前损失: 1.833212e-07
# LBFGS外循环 242/500, 当前损失: 1.833212e-07
# LBFGS外循环 243/500, 当前损失: 1.833212e-07
# LBFGS Iter: 7900, Loss: 1.833213e-07, PDE: 1.441665e-07, BC: 1.863477e-09, IC: 2.051999e-09
# LBFGS外循环 244/500, 当前损失: 1.833212e-07
# LBFGS外循环 245/500, 当前损失: 1.833212e-07
# LBFGS外循环 246/500, 当前损失: 1.833212e-07
# LBFGS外循环 247/500, 当前损失: 1.833212e-07
# LBFGS外循环 248/500, 当前损失: 1.833212e-07
# LBFGS外循环 249/500, 当前损失: 1.833212e-07
# LBFGS外循环 250/500, 当前损失: 1.833212e-07
# LBFGS外循环 251/500, 当前损失: 1.833212e-07
# LBFGS外循环 252/500, 当前损失: 1.833212e-07
# LBFGS外循环 253/500, 当前损失: 1.833212e-07
# LBFGS外循环 254/500, 当前损失: 1.833212e-07
# LBFGS外循环 255/500, 当前损失: 1.833212e-07
# LBFGS外循环 256/500, 当前损失: 1.833212e-07
# LBFGS外循环 257/500, 当前损失: 1.833212e-07
# LBFGS外循环 258/500, 当前损失: 1.833212e-07
# LBFGS外循环 259/500, 当前损失: 1.833212e-07
# LBFGS外循环 260/500, 当前损失: 1.833212e-07
# LBFGS Iter: 8000, Loss: 1.833228e-07, PDE: 1.441668e-07, BC: 1.863434e-09, IC: 2.052166e-09
# LBFGS外循环 261/500, 当前损失: 1.833212e-07
# LBFGS外循环 262/500, 当前损失: 1.833212e-07
# LBFGS外循环 263/500, 当前损失: 1.833212e-07
# LBFGS外循环 264/500, 当前损失: 1.833212e-07
# LBFGS外循环 265/500, 当前损失: 1.833212e-07
# LBFGS外循环 266/500, 当前损失: 1.833212e-07
# LBFGS外循环 267/500, 当前损失: 1.833212e-07
# LBFGS外循环 268/500, 当前损失: 1.833212e-07
# LBFGS外循环 269/500, 当前损失: 1.833212e-07
# LBFGS外循环 270/500, 当前损失: 1.833212e-07
# LBFGS外循环 271/500, 当前损失: 1.833212e-07
# LBFGS外循环 272/500, 当前损失: 1.833212e-07
# LBFGS外循环 273/500, 当前损失: 1.833212e-07
# LBFGS外循环 274/500, 当前损失: 1.833212e-07
# LBFGS外循环 275/500, 当前损失: 1.833212e-07
# LBFGS外循环 276/500, 当前损失: 1.833212e-07
# LBFGS外循环 277/500, 当前损失: 1.833212e-07
# LBFGS Iter: 8100, Loss: 1.833212e-07, PDE: 1.441665e-07, BC: 1.863477e-09, IC: 2.051994e-09
# LBFGS外循环 278/500, 当前损失: 1.833212e-07
# LBFGS外循环 279/500, 当前损失: 1.833212e-07
# LBFGS外循环 280/500, 当前损失: 1.833212e-07
# LBFGS外循环 281/500, 当前损失: 1.833212e-07
# LBFGS外循环 282/500, 当前损失: 1.833212e-07
# LBFGS外循环 283/500, 当前损失: 1.833212e-07
# LBFGS外循环 284/500, 当前损失: 1.833212e-07
# LBFGS外循环 285/500, 当前损失: 1.833212e-07
# LBFGS外循环 286/500, 当前损失: 1.833212e-07
# LBFGS外循环 287/500, 当前损失: 1.833212e-07
# LBFGS外循环 288/500, 当前损失: 1.833212e-07
# LBFGS外循环 289/500, 当前损失: 1.833212e-07
# LBFGS外循环 290/500, 当前损失: 1.833212e-07
# LBFGS外循环 291/500, 当前损失: 1.833212e-07
# LBFGS外循环 292/500, 当前损失: 1.833212e-07
# LBFGS外循环 293/500, 当前损失: 1.833212e-07
# LBFGS Iter: 8200, Loss: 1.833213e-07, PDE: 1.441665e-07, BC: 1.863477e-09, IC: 2.051999e-09
# LBFGS外循环 294/500, 当前损失: 1.833212e-07
# LBFGS外循环 295/500, 当前损失: 1.833212e-07
# LBFGS外循环 296/500, 当前损失: 1.833212e-07
# LBFGS外循环 297/500, 当前损失: 1.833212e-07
# LBFGS外循环 298/500, 当前损失: 1.833212e-07
# LBFGS外循环 299/500, 当前损失: 1.833212e-07
# LBFGS外循环 300/500, 当前损失: 1.833212e-07
# LBFGS外循环 301/500, 当前损失: 1.833212e-07
# LBFGS外循环 302/500, 当前损失: 1.833212e-07
# LBFGS外循环 303/500, 当前损失: 1.833212e-07
# LBFGS外循环 304/500, 当前损失: 1.833212e-07
# LBFGS外循环 305/500, 当前损失: 1.833212e-07
# LBFGS外循环 306/500, 当前损失: 1.833212e-07
# LBFGS外循环 307/500, 当前损失: 1.833212e-07
# LBFGS外循环 308/500, 当前损失: 1.833212e-07
# LBFGS外循环 309/500, 当前损失: 1.833212e-07
# LBFGS外循环 310/500, 当前损失: 1.833212e-07
# LBFGS Iter: 8300, Loss: 1.833228e-07, PDE: 1.441668e-07, BC: 1.863434e-09, IC: 2.052166e-09
# LBFGS外循环 311/500, 当前损失: 1.833212e-07
# LBFGS外循环 312/500, 当前损失: 1.833212e-07
# LBFGS外循环 313/500, 当前损失: 1.833212e-07
# LBFGS外循环 314/500, 当前损失: 1.833212e-07
# LBFGS外循环 315/500, 当前损失: 1.833212e-07
# LBFGS外循环 316/500, 当前损失: 1.833212e-07
# LBFGS外循环 317/500, 当前损失: 1.833212e-07
# LBFGS外循环 318/500, 当前损失: 1.833212e-07
# LBFGS外循环 319/500, 当前损失: 1.833212e-07
# LBFGS外循环 320/500, 当前损失: 1.833212e-07
# LBFGS外循环 321/500, 当前损失: 1.833212e-07
# LBFGS外循环 322/500, 当前损失: 1.833212e-07
# LBFGS外循环 323/500, 当前损失: 1.833212e-07
# LBFGS外循环 324/500, 当前损失: 1.833212e-07
# LBFGS外循环 325/500, 当前损失: 1.833212e-07
# LBFGS外循环 326/500, 当前损失: 1.833212e-07
# LBFGS外循环 327/500, 当前损失: 1.833212e-07
# LBFGS Iter: 8400, Loss: 1.833212e-07, PDE: 1.441665e-07, BC: 1.863477e-09, IC: 2.051994e-09
# LBFGS外循环 328/500, 当前损失: 1.833212e-07
# LBFGS外循环 329/500, 当前损失: 1.833212e-07
# LBFGS外循环 330/500, 当前损失: 1.833212e-07
# LBFGS外循环 331/500, 当前损失: 1.833212e-07
# LBFGS外循环 332/500, 当前损失: 1.833212e-07
# LBFGS外循环 333/500, 当前损失: 1.833212e-07
# LBFGS外循环 334/500, 当前损失: 1.833212e-07
# LBFGS外循环 335/500, 当前损失: 1.833212e-07
# LBFGS外循环 336/500, 当前损失: 1.833212e-07
# LBFGS外循环 337/500, 当前损失: 1.833212e-07
# LBFGS外循环 338/500, 当前损失: 1.833212e-07
# LBFGS外循环 339/500, 当前损失: 1.833212e-07
# LBFGS外循环 340/500, 当前损失: 1.833212e-07
# LBFGS外循环 341/500, 当前损失: 1.833212e-07
# LBFGS外循环 342/500, 当前损失: 1.833212e-07
# LBFGS外循环 343/500, 当前损失: 1.833212e-07
# LBFGS Iter: 8500, Loss: 1.833213e-07, PDE: 1.441665e-07, BC: 1.863477e-09, IC: 2.051999e-09
# LBFGS外循环 344/500, 当前损失: 1.833212e-07
# LBFGS外循环 345/500, 当前损失: 1.833212e-07
# LBFGS外循环 346/500, 当前损失: 1.833212e-07
# LBFGS外循环 347/500, 当前损失: 1.833212e-07
# LBFGS外循环 348/500, 当前损失: 1.833212e-07
# LBFGS外循环 349/500, 当前损失: 1.833212e-07
# LBFGS外循环 350/500, 当前损失: 1.833212e-07
# LBFGS外循环 351/500, 当前损失: 1.833212e-07
# LBFGS外循环 352/500, 当前损失: 1.833212e-07
# LBFGS外循环 353/500, 当前损失: 1.833212e-07
# LBFGS外循环 354/500, 当前损失: 1.833212e-07
# LBFGS外循环 355/500, 当前损失: 1.833212e-07
# LBFGS外循环 356/500, 当前损失: 1.833212e-07
# LBFGS外循环 357/500, 当前损失: 1.833212e-07
# LBFGS外循环 358/500, 当前损失: 1.833212e-07
# LBFGS外循环 359/500, 当前损失: 1.833212e-07
# LBFGS外循环 360/500, 当前损失: 1.833212e-07
# LBFGS Iter: 8600, Loss: 1.833228e-07, PDE: 1.441668e-07, BC: 1.863434e-09, IC: 2.052166e-09
# LBFGS外循环 361/500, 当前损失: 1.833212e-07
# LBFGS外循环 362/500, 当前损失: 1.833212e-07
# LBFGS外循环 363/500, 当前损失: 1.833212e-07
# LBFGS外循环 364/500, 当前损失: 1.833212e-07
# LBFGS外循环 365/500, 当前损失: 1.833212e-07
# LBFGS外循环 366/500, 当前损失: 1.833212e-07
# LBFGS外循环 367/500, 当前损失: 1.833212e-07
# LBFGS外循环 368/500, 当前损失: 1.833212e-07
# LBFGS外循环 369/500, 当前损失: 1.833212e-07
# LBFGS外循环 370/500, 当前损失: 1.833212e-07
# LBFGS外循环 371/500, 当前损失: 1.833212e-07
# LBFGS外循环 372/500, 当前损失: 1.833212e-07
# LBFGS外循环 373/500, 当前损失: 1.833212e-07
# LBFGS外循环 374/500, 当前损失: 1.833212e-07
# LBFGS外循环 375/500, 当前损失: 1.833212e-07
# LBFGS外循环 376/500, 当前损失: 1.833212e-07
# LBFGS外循环 377/500, 当前损失: 1.833212e-07
# LBFGS Iter: 8700, Loss: 1.833212e-07, PDE: 1.441665e-07, BC: 1.863477e-09, IC: 2.051994e-09
# LBFGS外循环 378/500, 当前损失: 1.833212e-07
# LBFGS外循环 379/500, 当前损失: 1.833212e-07
# LBFGS外循环 380/500, 当前损失: 1.833212e-07
# LBFGS外循环 381/500, 当前损失: 1.833212e-07
# LBFGS外循环 382/500, 当前损失: 1.833212e-07
# LBFGS外循环 383/500, 当前损失: 1.833212e-07
# LBFGS外循环 384/500, 当前损失: 1.833212e-07
# LBFGS外循环 385/500, 当前损失: 1.833212e-07
# LBFGS外循环 386/500, 当前损失: 1.833212e-07
# LBFGS外循环 387/500, 当前损失: 1.833212e-07
# LBFGS外循环 388/500, 当前损失: 1.833212e-07
# LBFGS外循环 389/500, 当前损失: 1.833212e-07
# LBFGS外循环 390/500, 当前损失: 1.833212e-07
# LBFGS外循环 391/500, 当前损失: 1.833212e-07
# LBFGS外循环 392/500, 当前损失: 1.833212e-07
# LBFGS外循环 393/500, 当前损失: 1.833212e-07
# LBFGS Iter: 8800, Loss: 1.833213e-07, PDE: 1.441665e-07, BC: 1.863477e-09, IC: 2.051999e-09
# LBFGS外循环 394/500, 当前损失: 1.833212e-07
# LBFGS外循环 395/500, 当前损失: 1.833212e-07
# LBFGS外循环 396/500, 当前损失: 1.833212e-07
# LBFGS外循环 397/500, 当前损失: 1.833212e-07
# LBFGS外循环 398/500, 当前损失: 1.833212e-07
# LBFGS外循环 399/500, 当前损失: 1.833212e-07
# LBFGS外循环 400/500, 当前损失: 1.833212e-07
# LBFGS外循环 401/500, 当前损失: 1.833212e-07
# LBFGS外循环 402/500, 当前损失: 1.833212e-07
# LBFGS外循环 403/500, 当前损失: 1.833212e-07
# LBFGS外循环 404/500, 当前损失: 1.833212e-07
# LBFGS外循环 405/500, 当前损失: 1.833212e-07
# LBFGS外循环 406/500, 当前损失: 1.833212e-07
# LBFGS外循环 407/500, 当前损失: 1.833212e-07
# LBFGS外循环 408/500, 当前损失: 1.833212e-07
# LBFGS外循环 409/500, 当前损失: 1.833212e-07
# LBFGS外循环 410/500, 当前损失: 1.833212e-07
# LBFGS Iter: 8900, Loss: 1.833228e-07, PDE: 1.441668e-07, BC: 1.863434e-09, IC: 2.052166e-09
# LBFGS外循环 411/500, 当前损失: 1.833212e-07
# LBFGS外循环 412/500, 当前损失: 1.833212e-07
# LBFGS外循环 413/500, 当前损失: 1.833212e-07
# LBFGS外循环 414/500, 当前损失: 1.833212e-07
# LBFGS外循环 415/500, 当前损失: 1.833212e-07
# LBFGS外循环 416/500, 当前损失: 1.833212e-07
# LBFGS外循环 417/500, 当前损失: 1.833212e-07
# LBFGS外循环 418/500, 当前损失: 1.833212e-07
# LBFGS外循环 419/500, 当前损失: 1.833212e-07
# LBFGS外循环 420/500, 当前损失: 1.833212e-07
# LBFGS外循环 421/500, 当前损失: 1.833212e-07
# LBFGS外循环 422/500, 当前损失: 1.833212e-07
# LBFGS外循环 423/500, 当前损失: 1.833212e-07
# LBFGS外循环 424/500, 当前损失: 1.833212e-07
# LBFGS外循环 425/500, 当前损失: 1.833212e-07
# LBFGS外循环 426/500, 当前损失: 1.833212e-07
# LBFGS外循环 427/500, 当前损失: 1.833212e-07
# LBFGS Iter: 9000, Loss: 1.833212e-07, PDE: 1.441665e-07, BC: 1.863477e-09, IC: 2.051994e-09
# LBFGS外循环 428/500, 当前损失: 1.833212e-07
# LBFGS外循环 429/500, 当前损失: 1.833212e-07
# LBFGS外循环 430/500, 当前损失: 1.833212e-07
# LBFGS外循环 431/500, 当前损失: 1.833212e-07
# LBFGS外循环 432/500, 当前损失: 1.833212e-07
# LBFGS外循环 433/500, 当前损失: 1.833212e-07
# LBFGS外循环 434/500, 当前损失: 1.833212e-07
# LBFGS外循环 435/500, 当前损失: 1.833212e-07
# LBFGS外循环 436/500, 当前损失: 1.833212e-07
# LBFGS外循环 437/500, 当前损失: 1.833212e-07
# LBFGS外循环 438/500, 当前损失: 1.833212e-07
# LBFGS外循环 439/500, 当前损失: 1.833212e-07
# LBFGS外循环 440/500, 当前损失: 1.833212e-07
# LBFGS外循环 441/500, 当前损失: 1.833212e-07
# LBFGS外循环 442/500, 当前损失: 1.833212e-07
# LBFGS外循环 443/500, 当前损失: 1.833212e-07
# LBFGS Iter: 9100, Loss: 1.833213e-07, PDE: 1.441665e-07, BC: 1.863477e-09, IC: 2.051999e-09
# LBFGS外循环 444/500, 当前损失: 1.833212e-07
# LBFGS外循环 445/500, 当前损失: 1.833212e-07
# LBFGS外循环 446/500, 当前损失: 1.833212e-07
# LBFGS外循环 447/500, 当前损失: 1.833212e-07
# LBFGS外循环 448/500, 当前损失: 1.833212e-07
# LBFGS外循环 449/500, 当前损失: 1.833212e-07
# LBFGS外循环 450/500, 当前损失: 1.833212e-07
# LBFGS外循环 451/500, 当前损失: 1.833212e-07
# LBFGS外循环 452/500, 当前损失: 1.833212e-07
# LBFGS外循环 453/500, 当前损失: 1.833212e-07
# LBFGS外循环 454/500, 当前损失: 1.833212e-07
# LBFGS外循环 455/500, 当前损失: 1.833212e-07
# LBFGS外循环 456/500, 当前损失: 1.833212e-07
# LBFGS外循环 457/500, 当前损失: 1.833212e-07
# LBFGS外循环 458/500, 当前损失: 1.833212e-07
# LBFGS外循环 459/500, 当前损失: 1.833212e-07
# LBFGS外循环 460/500, 当前损失: 1.833212e-07
# LBFGS Iter: 9200, Loss: 1.833228e-07, PDE: 1.441668e-07, BC: 1.863434e-09, IC: 2.052166e-09
# LBFGS外循环 461/500, 当前损失: 1.833212e-07
# LBFGS外循环 462/500, 当前损失: 1.833212e-07
# LBFGS外循环 463/500, 当前损失: 1.833212e-07
# LBFGS外循环 464/500, 当前损失: 1.833212e-07
# LBFGS外循环 465/500, 当前损失: 1.833212e-07
# LBFGS外循环 466/500, 当前损失: 1.833212e-07
# LBFGS外循环 467/500, 当前损失: 1.833212e-07
# LBFGS外循环 468/500, 当前损失: 1.833212e-07
# LBFGS外循环 469/500, 当前损失: 1.833212e-07
# LBFGS外循环 470/500, 当前损失: 1.833212e-07
# LBFGS外循环 471/500, 当前损失: 1.833212e-07
# LBFGS外循环 472/500, 当前损失: 1.833212e-07
# LBFGS外循环 473/500, 当前损失: 1.833212e-07
# LBFGS外循环 474/500, 当前损失: 1.833212e-07
# LBFGS外循环 475/500, 当前损失: 1.833212e-07
# LBFGS外循环 476/500, 当前损失: 1.833212e-07
# LBFGS外循环 477/500, 当前损失: 1.833212e-07
# LBFGS Iter: 9300, Loss: 1.833212e-07, PDE: 1.441665e-07, BC: 1.863477e-09, IC: 2.051994e-09
# LBFGS外循环 478/500, 当前损失: 1.833212e-07
# LBFGS外循环 479/500, 当前损失: 1.833212e-07
# LBFGS外循环 480/500, 当前损失: 1.833212e-07
# LBFGS外循环 481/500, 当前损失: 1.833212e-07
# LBFGS外循环 482/500, 当前损失: 1.833212e-07
# LBFGS外循环 483/500, 当前损失: 1.833212e-07
# LBFGS外循环 484/500, 当前损失: 1.833212e-07
# LBFGS外循环 485/500, 当前损失: 1.833212e-07
# LBFGS外循环 486/500, 当前损失: 1.833212e-07
# LBFGS外循环 487/500, 当前损失: 1.833212e-07
# LBFGS外循环 488/500, 当前损失: 1.833212e-07
# LBFGS外循环 489/500, 当前损失: 1.833212e-07
# LBFGS外循环 490/500, 当前损失: 1.833212e-07
# LBFGS外循环 491/500, 当前损失: 1.833212e-07
# LBFGS外循环 492/500, 当前损失: 1.833212e-07
# LBFGS外循环 493/500, 当前损失: 1.833212e-07
# LBFGS Iter: 9400, Loss: 1.833213e-07, PDE: 1.441665e-07, BC: 1.863477e-09, IC: 2.051999e-09
# LBFGS外循环 494/500, 当前损失: 1.833212e-07
# LBFGS外循环 495/500, 当前损失: 1.833212e-07
# LBFGS外循环 496/500, 当前损失: 1.833212e-07
# LBFGS外循环 497/500, 当前损失: 1.833212e-07
# LBFGS外循环 498/500, 当前损失: 1.833212e-07
# LBFGS外循环 499/500, 当前损失: 1.833212e-07
# LBFGS外循环 500/500, 当前损失: 1.833212e-07
# 优化完成!

# %%
# 修改可视化部分 - 更新网格范围
# 创建网格点
nx, nt = 100, 100
x = torch.linspace(-10, 10, nx).reshape(-1, 1)  # x范围[-10,10]
t = torch.linspace(0, 12, nt).reshape(-1, 1)   # t范围[0,12]

X, T = torch.meshgrid(x.squeeze(), t.squeeze(), indexing='ij')

X_flat = X.reshape(-1, 1)
T_flat = T.reshape(-1, 1)

# 组合输入
X_test = torch.cat([T_flat, X_flat], dim=1)

# 模型预测
with torch.no_grad():
    outputs_pred = model(X_test)
    u_pred = outputs_pred[:, 0:1].reshape(nx, nt).detach().numpy()
    v_pred = outputs_pred[:, 1:2].reshape(nx, nt).detach().numpy()

# 解析解
u_exact = analytical_solution(T_flat, X_flat).reshape(nx, nt).detach().numpy()
v_exact = analytical_solution_v(T_flat, X_flat).reshape(nx, nt).detach().numpy()

# 计算误差
u_error = np.abs(u_pred - u_exact)
v_error = np.abs(v_pred - v_exact)

# 显示热图对比（现在显示u和v）
plt.figure(figsize=(18, 12))

# u的对比
plt.subplot(231)
im = plt.pcolormesh(T.numpy(), X.numpy(), u_exact, cmap='jet', shading='auto')
plt.colorbar(im)
plt.xlabel('t', fontsize=12)
plt.ylabel('x', fontsize=12)
plt.title('Analytical Solution u(x,t)', fontsize=14)

plt.subplot(232)
im = plt.pcolormesh(T.numpy(), X.numpy(), u_pred, cmap='jet', shading='auto')
plt.colorbar(im)
plt.xlabel('t', fontsize=12)
plt.ylabel('x', fontsize=12)
plt.title('Predicted Solution u(x,t)', fontsize=14)

plt.subplot(233)
im = plt.pcolormesh(T.numpy(), X.numpy(), u_error, cmap='jet', shading='auto')
plt.colorbar(im)
plt.xlabel('t', fontsize=12)
plt.ylabel('x', fontsize=12)
plt.title('Absolute Error', fontsize=14)

plt.tight_layout()
plt.show()

# 计算L2误差
total_u_l2_error = np.sqrt(np.mean(np.square(u_pred - u_exact)))
total_v_l2_error = np.sqrt(np.mean(np.square(v_pred - v_exact)))
print(f"u的L2误差: {total_u_l2_error:.6f}")
print(f"v的L2误差: {total_v_l2_error:.6f}")
# Out:
# u的L2误差: 0.009959
# v的L2误差: 0.002518

# %%
# 创建单独的大图显示u的三维对比
fig = plt.figure(figsize=(15, 5))

# 解析解
ax1 = fig.add_subplot(1, 3, 1, projection='3d')
surf1 = ax1.plot_surface(X.numpy(), T.numpy(), u_exact, 
                        cmap='viridis', alpha=0.9, linewidth=0.5, 
                        antialiased=True, linestyle='--')
ax1.set_xlabel('t', fontsize=12)
ax1.set_ylabel('x', fontsize=12)
ax1.set_zlabel('u(x,t)', fontsize=12)
ax1.set_title('Analytical Solution', fontsize=14, fontweight='bold')
ax1.view_init(elev=25, azim=45)
# 移除colorbar

# 设置坐标轴反向
ax1.invert_xaxis()  # t轴反向：从12到0
ax1.invert_yaxis()  # x轴反向：从10到-10

# PINN预测解
ax2 = fig.add_subplot(1, 3, 2, projection='3d')
surf2 = ax2.plot_surface(X.numpy(), T.numpy(), u_pred, 
                        cmap='viridis', alpha=0.9, linewidth=0.5, 
                        antialiased=True, linestyle='--')
ax2.set_xlabel('t', fontsize=12)
ax2.set_ylabel('x', fontsize=12)
ax2.set_zlabel('u(x,t)', fontsize=12)
ax2.set_title('PINN Prediction', fontsize=14, fontweight='bold')
ax2.view_init(elev=25, azim=45)
# 移除colorbar

# 设置坐标轴反向
ax2.invert_xaxis()  # t轴反向：从12到0
ax2.invert_yaxis()  # x轴反向：从10到-10

plt.tight_layout()
plt.show()

# %%
# 绘制特定时间切片的对比图
def plot_time_slices():
    """绘制不同时间点的解的切片对比"""
    time_points = [0, 3, 6, 9, 12]  # 选择几个时间点
    
    fig, axes = plt.subplots(2, 3, figsize=(18, 10))
    axes = axes.flatten()
    
    x_slice = torch.linspace(-10, 10, 200).reshape(-1, 1)
    
    for i, t_val in enumerate(time_points):
        if i >= 6:  # 只有6个子图
            break
            
        t_slice = torch.full_like(x_slice, t_val)
        x_test_slice = torch.cat([t_slice, x_slice], dim=1)
        
        # 模型预测
        with torch.no_grad():
            outputs_slice = model(x_test_slice)
            u_pred_slice = outputs_slice[:, 0:1].detach().numpy()
        
        # 解析解
        u_exact_slice = analytical_solution(t_slice, x_slice).detach().numpy()
        
        # 绘制对比
        axes[i].plot(x_slice.numpy(), u_exact_slice, 'b-', linewidth=2, label='Analytical')
        axes[i].plot(x_slice.numpy(), u_pred_slice, 'r--', linewidth=2, label='PINN')
        axes[i].set_xlabel('x', fontsize=12)
        axes[i].set_ylabel('u(x,t)', fontsize=12)
        axes[i].set_title(f't = {t_val}', fontsize=14)
        axes[i].grid(True, alpha=0.3)
        axes[i].legend()
        
        # 计算该时间点的误差
        error_slice = np.abs(u_pred_slice - u_exact_slice)
        max_error = np.max(error_slice)
        axes[i].text(0.02, 0.98, f'Max Error: {max_error:.4f}', 
                    transform=axes[i].transAxes, fontsize=10,
                    verticalalignment='top',
                    bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))
    
    # 如果有空的子图，隐藏它
    if len(time_points) < 6:
        axes[5].set_visible(False)
    
    plt.tight_layout()
    plt.suptitle('Solution Comparison at Different Time Points', fontsize=16, y=1.02)
    plt.show()

# 调用函数绘制时间切片对比
plot_time_slices()

# %%
# 修改L2误差计算函数的x_range参数
def compute_and_plot_l2_error(u_analytical, u_predicted, t_points, x_range):
    """计算并绘制不同时间点上的L2误差"""
    # 计算空间步长(用于数值积分)
    dx = (x_range[1] - x_range[0]) / (u_analytical.shape[0] - 1)
    
    # 初始化L2误差数组
    l2_errors_u = np.zeros(len(t_points))
    
    # 对每个时间点计算L2误差
    for i in range(len(t_points)):
        # 计算u的L2误差
        squared_error_u = (u_analytical[:, i] - u_predicted[:, i])**2
        l2_errors_u[i] = np.sqrt(np.sum(squared_error_u) * dx)
    
    # 绘制L2误差随时间的变化
    plt.figure(figsize=(10, 6))
    plt.plot(t_points, l2_errors_u, 'r-', linewidth=2)
    plt.grid(True)
    plt.xlabel('t', fontsize=14)
    plt.ylabel('L2 Error', fontsize=14)
    plt.legend()
    
    # 添加均方根误差信息
    rmse_u = np.sqrt(np.mean(l2_errors_u**2))
    plt.text(0.05, 0.95, f'u RMSE: {rmse_u:.6f}', 
             transform=plt.gca().transAxes, fontsize=12, 
             bbox=dict(facecolor='white', alpha=0.8))
    
    plt.tight_layout()
    plt.show()
    
    return l2_errors_u

# 使用该函数计算并绘制L2误差
t_points = t.squeeze().numpy()  # 时间点数组
x_range = [-10, 10]  # 修改x的范围为[-10, 10]

# 计算并绘制L2误差
l2_errors_u = compute_and_plot_l2_error(
    u_analytical=u_exact, 
    u_predicted=u_pred,
    t_points=t_points,
    x_range=x_range
)
# Out:
# D:\TempFiles\ipykernel_11984\1005194064.py:22: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
